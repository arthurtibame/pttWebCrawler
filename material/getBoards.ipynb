# %%
#!/usr/bin/env python
# coding: utf-8
'''
To get each board name.

getPapularBoard() -> Dict[boardname]: [boardurl, boardtitle, boardclass]
    Return a list of each papular board name

getAllBoard() -> List[str]
    Return a list of most of board name
'''

import requests
from bs4 import BeautifulSoup

# Set headers
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'}

# Target url
papular_board_url = 'https://www.ptt.cc/bbs/index.html'

def getPapularBoards():
    board_info = dict()
    res = requests.get(papular_board_url, headers=headers)
    soup = BeautifulSoup(res.text, 'html.parser')
    boards_list = soup.select('a.board')
    for b in boards_list:
        board_name = b.select('div.board-name')[0].text
        board_url = 'https://www.ptt.cc' + b['href']
        board_title = b.select('div.board-title')[0].text
        board_class = b.select('div.board-class')[0].text

        tmp_dict = {
            'board_url': board_url,
            'board_title': board_title,
            'board_class': board_class
        }
        board_info[board_name] = tmp_dict
    
    return board_info

def getAllBoards():
    pass

# %%
t = getPapularBoards()
len(t)
# Out:
# 128

# %%
board_info = dict()
res = requests.get(papular_board_url, headers=headers)
soup = BeautifulSoup(res.text, 'html.parser')
boards_list = soup.select('a.board')
for b in boards_list:
    board_name = b.select('div.board-name')[0].text
    board_url = 'https://www.ptt.cc' + b['href']
    board_title = b.select('div.board-title')[0].text
    board_class = b.select('div.board-class')[0].text
    
    tmp_dict = {
        'board_url': board_url,
        'board_title': board_title,
        'board_class': board_class
    }
    board_info[board_name] = tmp_dict
# Out:
# [<a class="board" href="/bbs/Gossiping/index.html">
#  <div class="board-name">Gossiping</div>
#  <div class="board-nuser"><span class="hl f2">30124</span></div>
#  <div class="board-class">綜合</div>
#  <div class="board-title">◎版主徵選中，截止時間4/16(16:04)</div>
#  </a>,
#  <a class="board" href="/bbs/Stock/index.html">
#  <div class="board-name">Stock</div>
#  <div class="board-nuser"><span class="hl f4">6988</span></div>
#  <div class="board-class">學術</div>
#  <div class="board-title">◎3/30 0：00起 板規處分提高一級</div>
#  </a>,
#  <a class="board" href="/bbs/Baseball/index.html">
#  <div class="board-name">Baseball</div>
#  <div class="board-nuser"><span class="hl f1">4993</span></div>
#  <div class="board-class">棒球</div>
#  <div class="board-title">◎[棒球] 中職31年開幕</div>
#  </a>,
#  <a class="board" href="/bbs/C_Chat/index.html">
#  <div class="board-name">C_Chat</div>
#  <div class="board-nuser"><span class="hl f1">3417</span></div>
#  <div class="board-class">閒談</div>
#  <div class="board-title">◎[希洽] 臨時活動：系列文推噓投票</div>
#  </a>,
#  <a class="board" href="/bbs/Elephants/index.html">
#  <div class="board-name">Elephants</div>
#  <div class="board-nuser"><span class="hl f1">2120</span></div>
#  <div class="board-class">CPBL</div>
#  <div class="board-title">◎只能看轉播的日子</div>
#  </a>,
#  <a class="board" href="/bbs/Lifeismoney/index.html">
#  <div class="board-name">Lifeismoney</div>
#  <div class="board-nuser"><span class="hl">1674</span></div>
#  <div class="board-class">省錢</div>
#  <div class="board-title">◎[省錢] 省錢板 請先看置底板規</div>
#  </a>,
#  <a class="board" href="/bbs/NBA/index.html">
#  <div class="board-name">NBA</div>
#  <div class="board-nuser"><span class="hl">1318</span></div>
#  <div class="board-class">籃球</div>
#  <div class="board-title">◎[NBA] 球季無限期停賽</div>
#  </a>,
#  <a class="board" href="/bbs/sex/index.html">
#  <div class="board-name">sex</div>
#  <div class="board-nuser"><span class="hl">1222</span></div>
#  <div class="board-class">男女</div>
#  <div class="board-title">◎[西斯] 勤洗手 戴口罩 再♡♥</div>
#  </a>,
#  <a class="board" href="/bbs/Beauty/index.html">
#  <div class="board-name">Beauty</div>
#  <div class="board-nuser"><span class="hl">1185</span></div>
#  <div class="board-class">聊天</div>
#  <div class="board-title">◎《表特板》發文附圖</div>
#  </a>,
#  <a class="board" href="/bbs/LoL/index.html">
#  <div class="board-name">LoL</div>
#  <div class="board-nuser"><span class="hl">1171</span></div>
#  <div class="board-class">遊戲</div>
#  <div class="board-title">◎[LoL] 禁發Valorant文</div>
#  </a>,
#  <a class="board" href="/bbs/Tech_Job/index.html">
#  <div class="board-name">Tech_Job</div>
#  <div class="board-nuser"><span class="hl">1141</span></div>
#  <div class="board-class">工作</div>
#  <div class="board-title">◎[科技] 修機改善是設備終生職責</div>
#  </a>,
#  <a class="board" href="/bbs/car/index.html">
#  <div class="board-name">car</div>
#  <div class="board-nuser"><span class="hl">1117</span></div>
#  <div class="board-class">車車</div>
#  <div class="board-title">◎[汽車] 發文必須滿30字</div>
#  </a>,
#  <a class="board" href="/bbs/NSwitch/index.html">
#  <div class="board-name">NSwitch</div>
#  <div class="board-nuser"><span class="hl">1066</span></div>
#  <div class="board-class">主機</div>
#  <div class="board-title">◎[NS] 板上動森活動今日截止詳置底</div>
#  </a>,
#  <a class="board" href="/bbs/BabyMother/index.html">
#  <div class="board-name">BabyMother</div>
#  <div class="board-nuser"><span class="hl">869</span></div>
#  <div class="board-class">家庭</div>
#  <div class="board-title">◎[媽寶] 群組文僅限週四發表</div>
#  </a>,
#  <a class="board" href="/bbs/e-shopping/index.html">
#  <div class="board-name">e-shopping</div>
#  <div class="board-nuser"><span class="hl">794</span></div>
#  <div class="board-class">網購</div>
#  <div class="board-title">◎[ＥＳ] 板主徵求中喔</div>
#  </a>,
#  <a class="board" href="/bbs/WomenTalk/index.html">
#  <div class="board-name">WomenTalk</div>
#  <div class="board-nuser"><span class="hl">789</span></div>
#  <div class="board-class">聊天</div>
#  <div class="board-title">◎[女孩] 勤洗手 戴口罩</div>
#  </a>,
#  <a class="board" href="/bbs/MobileComm/index.html">
#  <div class="board-name">MobileComm</div>
#  <div class="board-nuser"><span class="hl">785</span></div>
#  <div class="board-class">資訊</div>
#  <div class="board-title">◎[通訊] 入板前請先詳閱板規</div>
#  </a>,
#  <a class="board" href="/bbs/Boy-Girl/index.html">
#  <div class="board-name">Boy-Girl</div>
#  <div class="board-nuser"><span class="hl">751</span></div>
#  <div class="board-class">心情</div>
#  <div class="board-title">◎[男女] c2-政治 加重罰則</div>
#  </a>,
#  <a class="board" href="/bbs/home-sale/index.html">
#  <div class="board-name">home-sale</div>
#  <div class="board-nuser"><span class="hl">724</span></div>
#  <div class="board-class">房屋</div>
#  <div class="board-title">◎[房屋] 請勿張貼無關本板之新聞</div>
#  </a>,
#  <a class="board" href="/bbs/PlayStation/index.html">
#  <div class="board-name">PlayStation</div>
#  <div class="board-nuser"><span class="hl">688</span></div>
#  <div class="board-class">主機</div>
#  <div class="board-title">◎[PS4] 4/15~4/28 PSN春季特賣!</div>
#  </a>,
#  <a class="board" href="/bbs/KoreaDrama/index.html">
#  <div class="board-name">KoreaDrama</div>
#  <div class="board-nuser"><span class="hl">664</span></div>
#  <div class="board-class">韓劇</div>
#  <div class="board-title">◎[韓劇] 最近很多人發文前不看板規</div>
#  </a>,
#  <a class="board" href="/bbs/Monkeys/index.html">
#  <div class="board-name">Monkeys</div>
#  <div class="board-nuser"><span class="hl">611</span></div>
#  <div class="board-class">CPBL</div>
#  <div class="board-title">◎樂天桃猿 置底活動-MVP由來你發問</div>
#  </a>,
#  <a class="board" href="/bbs/AnimalForest/index.html">
#  <div class="board-name">AnimalForest</div>
#  <div class="board-nuser"><span class="hl">592</span></div>
#  <div class="board-class">扮演</div>
#  <div class="board-title">◎[動森]動物森友會 板主徵選中</div>
#  </a>,
#  <a class="board" href="/bbs/movie/index.html">
#  <div class="board-name">movie</div>
#  <div class="board-nuser"><span class="hl">555</span></div>
#  <div class="board-class">綜合</div>
#  <div class="board-title">◎[電影] 進場戴口罩 勤洗手 保平安</div>
#  </a>,
#  <a class="board" href="/bbs/Lions/index.html">
#  <div class="board-name">Lions</div>
#  <div class="board-nuser"><span class="hl">545</span></div>
#  <div class="board-class">CPBL</div>
#  <div class="board-title">◎狂賀! 統一7-ELEVEn獅世界第一!</div>
#  </a>,
#  <a class="board" href="/bbs/KoreaStar/index.html">
#  <div class="board-name">KoreaStar</div>
#  <div class="board-nuser"><span class="hl">528</span></div>
#  <div class="board-class">韓國</div>
#  <div class="board-title">◎[韓星] 發/推文前請務必詳閱板規</div>
#  </a>,
#  <a class="board" href="/bbs/AllTogether/index.html">
#  <div class="board-name">AllTogether</div>
#  <div class="board-nuser"><span class="hl">509</span></div>
#  <div class="board-class">聯誼</div>
#  <div class="board-title">◎[歐兔] 發文前詳閱置底板規&amp;文摘</div>
#  </a>,
#  <a class="board" href="/bbs/joke/index.html">
#  <div class="board-name">joke</div>
#  <div class="board-nuser"><span class="hl">507</span></div>
#  <div class="board-class">娛樂</div>
#  <div class="board-title">◎[joke] 就可板</div>
#  </a>,
#  <a class="board" href="/bbs/Guardians/index.html">
#  <div class="board-name">Guardians</div>
#  <div class="board-nuser"><span class="hl">497</span></div>
#  <div class="board-class">CPBL</div>
#  <div class="board-title">◎一人一杯^o^一人一杯</div>
#  </a>,
#  <a class="board" href="/bbs/creditcard/index.html">
#  <div class="board-name">creditcard</div>
#  <div class="board-nuser"><span class="hl">488</span></div>
#  <div class="board-class">理財</div>
#  <div class="board-title">◎[信用卡] 新增[海外]分類範本</div>
#  </a>,
#  <a class="board" href="/bbs/iOS/index.html">
#  <div class="board-name">iOS</div>
#  <div class="board-nuser"><span class="hl">482</span></div>
#  <div class="board-class">系統</div>
#  <div class="board-title">◎[iOS] 嘿Siri 開啟妓院模式</div>
#  </a>,
#  <a class="board" href="/bbs/PC_Shopping/index.html">
#  <div class="board-name">PC_Shopping</div>
#  <div class="board-nuser"><span class="hl">479</span></div>
#  <div class="board-class">硬體</div>
#  <div class="board-title">◎[電蝦] 出入公共場所記得自身防護</div>
#  </a>,
#  <a class="board" href="/bbs/HatePolitics/index.html">
#  <div class="board-name">HatePolitics</div>
#  <div class="board-nuser"><span class="hl">449</span></div>
#  <div class="board-class">Hate</div>
#  <div class="board-title">◎[政黑] 小心病毒 做好防疫</div>
#  </a>,
#  <a class="board" href="/bbs/marvel/index.html">
#  <div class="board-name">marvel</div>
#  <div class="board-nuser"><span class="hl">444</span></div>
#  <div class="board-class">生二</div>
#  <div class="board-title">◎[媽佛] 諾亞方舟已開放登船囉!!!</div>
#  </a>,
#  <a class="board" href="/bbs/Kaohsiung/index.html">
#  <div class="board-name">Kaohsiung</div>
#  <div class="board-nuser"><span class="hl">417</span></div>
#  <div class="board-class">高雄</div>
#  <div class="board-title">◎[高雄] 曬太陽 戴口罩 勤洗手</div>
#  </a>,
#  <a class="board" href="/bbs/Tainan/index.html">
#  <div class="board-name">Tainan</div>
#  <div class="board-nuser"><span class="hl">396</span></div>
#  <div class="board-class">台南</div>
#  <div class="board-title">◎[台南] 置底有大台南活動整理</div>
#  </a>,
#  <a class="board" href="/bbs/Option/index.html">
#  <div class="board-name">Option</div>
#  <div class="board-nuser"><span class="hl">377</span></div>
#  <div class="board-class">學術</div>
#  <div class="board-title">◎[期權] 手續費洽broker板</div>
#  </a>,
#  <a class="board" href="/bbs/BeautySalon/index.html">
#  <div class="board-name">BeautySalon</div>
#  <div class="board-nuser"><span class="hl">362</span></div>
#  <div class="board-class">美容</div>
#  <div class="board-title">◎[美保] 本板新增板主刪除推文功能</div>
#  </a>,
#  <a class="board" href="/bbs/japanavgirls/index.html">
#  <div class="board-name">japanavgirls</div>
#  <div class="board-nuser"><span class="hl">361</span></div>
#  <div class="board-class">綜合</div>
#  <div class="board-title">◎AV女優板 清新、優質,神人照格式</div>
#  </a>,
#  <a class="board" href="/bbs/Japandrama/index.html">
#  <div class="board-name">Japandrama</div>
#  <div class="board-nuser"><span class="hl">356</span></div>
#  <div class="board-class">日劇</div>
#  <div class="board-title">◎[日劇] 宮藤官九郎 順利出院\0.0/</div>
#  </a>,
#  <a class="board" href="/bbs/SportLottery/index.html">
#  <div class="board-name">SportLottery</div>
#  <div class="board-nuser"><span class="hl">347</span></div>
#  <div class="board-class">博弈</div>
#  <div class="board-title">◎[運彩] 台灣運彩</div>
#  </a>,
#  <a class="board" href="/bbs/MakeUp/index.html">
#  <div class="board-name">MakeUp</div>
#  <div class="board-nuser"><span class="hl">340</span></div>
#  <div class="board-class">美容</div>
#  <div class="board-title">◎[美妝] 防疫安全 少用開架試用品</div>
#  </a>,
#  <a class="board" href="/bbs/marriage/index.html">
#  <div class="board-name">marriage</div>
#  <div class="board-nuser"><span class="hl">339</span></div>
#  <div class="board-class">婚姻</div>
#  <div class="board-title">◎戴口罩 勤洗手 平平安安 永結同心</div>
#  </a>,
#  <a class="board" href="/bbs/TaichungBun/index.html">
#  <div class="board-name">TaichungBun</div>
#  <div class="board-nuser"><span class="hl">329</span></div>
#  <div class="board-class">台中</div>
#  <div class="board-title">◎[台中] 看板小幫手強力徵求中</div>
#  </a>,
#  <a class="board" href="/bbs/Gamesale/index.html">
#  <div class="board-name">Gamesale</div>
#  <div class="board-nuser"><span class="hl">315</span></div>
#  <div class="board-class">綜合</div>
#  <div class="board-title">◎詐騙案件增多請多利用面交或網站</div>
#  </a>,
#  <a class="board" href="/bbs/Palmar_Drama/index.html">
#  <div class="board-name">Palmar_Drama</div>
#  <div class="board-nuser"><span class="hl">314</span></div>
#  <div class="board-class">布袋</div>
#  <div class="board-title">◎穿個界看到白髮旋渦眉</div>
#  </a>,
#  <a class="board" href="/bbs/Steam/index.html">
#  <div class="board-name">Steam</div>
#  <div class="board-nuser"><span class="hl">311</span></div>
#  <div class="board-class">平台</div>
#  <div class="board-title">◎本板禁止買賣合購代購代刷</div>
#  </a>,
#  <a class="board" href="/bbs/KR_Entertain/index.html">
#  <div class="board-name">KR_Entertain</div>
#  <div class="board-nuser"><span class="hl">306</span></div>
#  <div class="board-class">綜藝</div>
#  <div class="board-title">◎[韓綜] Show Me The 新板主!</div>
#  </a>,
#  <a class="board" href="/bbs/HardwareSale/index.html">
#  <div class="board-name">HardwareSale</div>
#  <div class="board-nuser"><span class="hl">279</span></div>
#  <div class="board-class">買賣</div>
#  <div class="board-title">◎[硬體買賣] 發文前請詳閱板規</div>
#  </a>,
#  <a class="board" href="/bbs/Salary/index.html">
#  <div class="board-name">Salary</div>
#  <div class="board-nuser"><span class="hl">275</span></div>
#  <div class="board-class">職場</div>
#  <div class="board-title">◎[職場] 工作職場板</div>
#  </a>,
#  <a class="board" href="/bbs/CFantasy/index.html">
#  <div class="board-name">CFantasy</div>
#  <div class="board-nuser"><span class="hl">274</span></div>
#  <div class="board-class">玄幻</div>
#  <div class="board-title">◎[玄幻] 你掉的是分類還是20字心得</div>
#  </a>,
#  <a class="board" href="/bbs/CVS/index.html">
#  <div class="board-name">CVS</div>
#  <div class="board-nuser"><span class="hl">271</span></div>
#  <div class="board-class">資訊</div>
#  <div class="board-title">◎一起逛超商 愛你愛你不寂寞</div>
#  </a>,
#  <a class="board" href="/bbs/ToS/index.html">
#  <div class="board-name">ToS</div>
#  <div class="board-nuser"><span class="hl">267</span></div>
#  <div class="board-class">轉珠</div>
#  <div class="board-title">◎[神魔] 公會任務+戰慄重開</div>
#  </a>,
#  <a class="board" href="/bbs/StupidClown/index.html">
#  <div class="board-name">StupidClown</div>
#  <div class="board-nuser"><span class="hl">254</span></div>
#  <div class="board-class">經歷</div>
#  <div class="board-title">◎ 哼哼哼哼</div>
#  </a>,
#  <a class="board" href="/bbs/China-Drama/index.html">
#  <div class="board-name">China-Drama</div>
#  <div class="board-nuser"><span class="hl">247</span></div>
#  <div class="board-class">陸劇</div>
#  <div class="board-title">◎[陸劇] 歡迎收看戲說如懿</div>
#  </a>,
#  <a class="board" href="/bbs/ONE_PIECE/index.html">
#  <div class="board-name">ONE_PIECE</div>
#  <div class="board-nuser"><span class="hl">225</span></div>
#  <div class="board-class">日本</div>
#  <div class="board-title">◎[海賊王]    977 宴會不開了</div>
#  </a>,
#  <a class="board" href="/bbs/PokemonGO/index.html">
#  <div class="board-name">PokemonGO</div>
#  <div class="board-nuser"><span class="hl">225</span></div>
#  <div class="board-class">抓寶</div>
#  <div class="board-title">◎[PMGO] 土地雲團體戰 </div>
#  </a>,
#  <a class="board" href="/bbs/PCReDive/index.html">
#  <div class="board-name">PCReDive</div>
#  <div class="board-nuser"><span class="hl">222</span></div>
#  <div class="board-class">手遊</div>
#  <div class="board-title">◎[公連] 三號板工補選開跑</div>
#  </a>,
#  <a class="board" href="/bbs/EAseries/index.html">
#  <div class="board-name">EAseries</div>
#  <div class="board-nuser"><span class="hl">222</span></div>
#  <div class="board-class">歐美</div>
#  <div class="board-title">◎[歐美影集] Stranger Things</div>
#  </a>,
#  <a class="board" href="/bbs/Hearthstone/index.html">
#  <div class="board-name">Hearthstone</div>
#  <div class="board-nuser"><span class="hl">215</span></div>
#  <div class="board-class">線上</div>
#  <div class="board-title">◎[爐石] 旅店大門永遠敞開著</div>
#  </a>,
#  <a class="board" href="/bbs/Soft_Job/index.html">
#  <div class="board-name">Soft_Job</div>
#  <div class="board-nuser"><span class="hl">192</span></div>
#  <div class="board-class">工作</div>
#  <div class="board-title">◎[軟工] 4/7~4/20 技術徵文投票</div>
#  </a>,
#  <a class="board" href="/bbs/Hsinchu/index.html">
#  <div class="board-name">Hsinchu</div>
#  <div class="board-nuser"><span class="hl">190</span></div>
#  <div class="board-class">新竹</div>
#  <div class="board-title">◎[新竹] 口罩在哪裡!!</div>
#  </a>,
#  <a class="board" href="/bbs/CarShop/index.html">
#  <div class="board-name">CarShop</div>
#  <div class="board-nuser"><span class="hl">188</span></div>
#  <div class="board-class">買賣</div>
#  <div class="board-title">◎[汽車買賣] 不懂就發文前先問板主</div>
#  </a>,
#  <a class="board" href="/bbs/TW_Entertain/index.html">
#  <div class="board-name">TW_Entertain</div>
#  <div class="board-nuser"><span class="hl">186</span></div>
#  <div class="board-class">綜藝</div>
#  <div class="board-title">◎[台綜] 人氣熊熊暴發 瞬間翻倍</div>
#  </a>,
#  <a class="board" href="/bbs/BuyTogether/index.html">
#  <div class="board-name">BuyTogether</div>
#  <div class="board-nuser"><span class="hl">185</span></div>
#  <div class="board-class">買賣</div>
#  <div class="board-title">◎[合購] 注意疫情 勤洗手最重要</div>
#  </a>,
#  <a class="board" href="/bbs/TaiwanDrama/index.html">
#  <div class="board-name">TaiwanDrama</div>
#  <div class="board-nuser"><span class="hl">185</span></div>
#  <div class="board-class">臺劇</div>
#  <div class="board-title">◎[臺劇] 今晚9點 姊妹們追吧</div>
#  </a>,
#  <a class="board" href="/bbs/Japan_Travel/index.html">
#  <div class="board-name">Japan_Travel</div>
#  <div class="board-nuser"><span class="hl">183</span></div>
#  <div class="board-class">旅遊</div>
#  <div class="board-title">◎日本緊急事態宣言 請暫緩出國計畫</div>
#  </a>,
#  <a class="board" href="/bbs/YuanChuang/index.html">
#  <div class="board-name">YuanChuang</div>
#  <div class="board-nuser"><span class="hl">178</span></div>
#  <div class="board-class">原創</div>
#  <div class="board-title">◎[原創] 四月徵文 - 年度必看！</div>
#  </a>,
#  <a class="board" href="/bbs/Brand/index.html">
#  <div class="board-name">Brand</div>
#  <div class="board-nuser"><span class="hl">178</span></div>
#  <div class="board-class">資訊</div>
#  <div class="board-title">◎   ＊* 布蘭德 細節的價值 ＊*</div>
#  </a>,
#  <a class="board" href="/bbs/Headphone/index.html">
#  <div class="board-name">Headphone</div>
#  <div class="board-nuser"><span class="hl">170</span></div>
#  <div class="board-class">資訊</div>
#  <div class="board-title">◎溫馨耳機板 心得文請多加敘述聽感</div>
#  </a>,
#  <a class="board" href="/bbs/biker/index.html">
#  <div class="board-name">biker</div>
#  <div class="board-nuser"><span class="hl">170</span></div>
#  <div class="board-class">車車</div>
#  <div class="board-title">◎[Biker] 連假行車出遊更要安全</div>
#  </a>,
#  <a class="board" href="/bbs/AC_In/index.html">
#  <div class="board-name">AC_In</div>
#  <div class="board-nuser"><span class="hl">166</span></div>
#  <div class="board-class">閒談</div>
#  <div class="board-title">◎[裏洽] 勤洗手</div>
#  </a>,
#  <a class="board" href="/bbs/Gov_owned/index.html">
#  <div class="board-name">Gov_owned</div>
#  <div class="board-nuser"><span class="hl">166</span></div>
#  <div class="board-class">國營</div>
#  <div class="board-title">◎[國營] 勤洗手戴口罩好防疫</div>
#  </a>,
#  <a class="board" href="/bbs/MuscleBeach/index.html">
#  <div class="board-name">MuscleBeach</div>
#  <div class="board-nuser"><span class="hl">152</span></div>
#  <div class="board-class">美體</div>
#  <div class="board-title">◎[健身] 發文前請務必詳閱板規</div>
#  </a>,
#  <a class="board" href="/bbs/lesbian/index.html">
#  <div class="board-name">lesbian</div>
#  <div class="board-nuser"><span class="hl">150</span></div>
#  <div class="board-class">男女</div>
#  <div class="board-title">◎[拉板] 洗手 口罩 顧健康</div>
#  </a>,
#  <a class="board" href="/bbs/basketballTW/index.html">
#  <div class="board-name">basketballTW</div>
#  <div class="board-nuser"><span class="hl">146</span></div>
#  <div class="board-class">籃球</div>
#  <div class="board-title">◎台灣籃球</div>
#  </a>,
#  <a class="board" href="/bbs/mobilesales/index.html">
#  <div class="board-name">mobilesales</div>
#  <div class="board-nuser"><span class="hl">145</span></div>
#  <div class="board-class">資訊</div>
#  <div class="board-title">◎☆面交☆ 別貪小便宜!小心詐騙!</div>
#  </a>,
#  <a class="board" href="/bbs/Finance/index.html">
#  <div class="board-name">Finance</div>
#  <div class="board-nuser"><span class="hl">140</span></div>
#  <div class="board-class">金融</div>
#  <div class="board-title">◎金融業板 半澤直樹2即將上映!!</div>
#  </a>,
#  <a class="board" href="/bbs/MH/index.html">
#  <div class="board-name">MH</div>
#  <div class="board-nuser"><span class="hl">138</span></div>
#  <div class="board-class">狩獵</div>
#  <div class="board-title">◎[MH] M級絢輝與煌黑龍即將登場</div>
#  </a>,
#  <a class="board" href="/bbs/WOW/index.html">
#  <div class="board-name">WOW</div>
#  <div class="board-nuser"><span class="hl">138</span></div>
#  <div class="board-class">線上</div>
#  <div class="board-title">◎[WoW] 在家練等就是最好的防疫</div>
#  </a>,
#  <a class="board" href="/bbs/watch/index.html">
#  <div class="board-name">watch</div>
#  <div class="board-nuser"><span class="hl">136</span></div>
#  <div class="board-class">購一</div>
#  <div class="board-title">◎[錶板] Show me your Watch!</div>
#  </a>,
#  <a class="board" href="/bbs/TypeMoon/index.html">
#  <div class="board-name">TypeMoon</div>
#  <div class="board-nuser"><span class="hl">135</span></div>
#  <div class="board-class">型月</div>
#  <div class="board-title">◎[ＴＭ] HF再度延期/2-5.2神之鋼彈</div>
#  </a>,
#  <a class="board" href="/bbs/PathofExile/index.html">
#  <div class="board-name">PathofExile</div>
#  <div class="board-nuser"><span class="hl">134</span></div>
#  <div class="board-class">線上</div>
#  <div class="board-title">◎[PoE] 開季自主隔離14天</div>
#  </a>,
#  <a class="board" href="/bbs/forsale/index.html">
#  <div class="board-name">forsale</div>
#  <div class="board-nuser"><span class="hl">131</span></div>
#  <div class="board-class">市場</div>
#  <div class="board-title">◎[跳蚤] 發文格式轉換舊制中</div>
#  </a>,
#  <a class="board" href="/bbs/E-appliance/index.html">
#  <div class="board-name">E-appliance</div>
#  <div class="board-nuser"><span class="hl">130</span></div>
#  <div class="board-class">資訊</div>
#  <div class="board-title">◎[家電] 徵板主&amp;禁買賣團購徵求文</div>
#  </a>,
#  <a class="board" href="/bbs/MacShop/index.html">
#  <div class="board-name">MacShop</div>
#  <div class="board-nuser"><span class="hl">128</span></div>
#  <div class="board-class">資訊</div>
#  <div class="board-title">◎發文前請詳閱版規</div>
#  </a>,
#  <a class="board" href="/bbs/cookclub/index.html">
#  <div class="board-name">cookclub</div>
#  <div class="board-nuser"><span class="hl">127</span></div>
#  <div class="board-class">烹飪</div>
#  <div class="board-title">◎歡迎分享手做美食</div>
#  </a>,
#  <a class="board" href="/bbs/Examination/index.html">
#  <div class="board-name">Examination</div>
#  <div class="board-nuser"><span class="hl">124</span></div>
#  <div class="board-class">考試</div>
#  <div class="board-title">◎[國考] 勤洗手戴口罩好防疫</div>
#  </a>,
#  <a class="board" href="/bbs/gay/index.html">
#  <div class="board-name">gay</div>
#  <div class="board-nuser"><span class="hl">123</span></div>
#  <div class="board-class">男女</div>
#  <div class="board-title">◎[甲板]勤洗手戴口罩配合防疫</div>
#  </a>,
#  <a class="board" href="/bbs/Food/index.html">
#  <div class="board-name">Food</div>
#  <div class="board-nuser"><span class="hl">123</span></div>
#  <div class="board-class">美食</div>
#  <div class="board-title">◎美食板</div>
#  </a>,
#  <a class="board" href="/bbs/GetMarry/index.html">
#  <div class="board-name">GetMarry</div>
#  <div class="board-nuser"><span class="hl">122</span></div>
#  <div class="board-class">結婚</div>
#  <div class="board-title">◎Getmarry-廣宣週三、交易週日</div>
#  </a>,
#  <a class="board" href="/bbs/Wanted/index.html">
#  <div class="board-name">Wanted</div>
#  <div class="board-nuser"><span class="hl">121</span></div>
#  <div class="board-class">徵求</div>
#  <div class="board-title">◎[汪踢] 一日汪踢人 終生汪踢魂</div>
#  </a>,
#  <a class="board" href="/bbs/Aviation/index.html">
#  <div class="board-name">Aviation</div>
#  <div class="board-nuser"><span class="hl">119</span></div>
#  <div class="board-class">交通</div>
#  <div class="board-title">◎[航空] 航空板/請用退票分類諮詢</div>
#  </a>,
#  <a class="board" href="/bbs/graduate/index.html">
#  <div class="board-name">graduate</div>
#  <div class="board-nuser"><span class="hl">114</span></div>
#  <div class="board-class">研究</div>
#  <div class="board-title">◎[研所] </div>
#  </a>,
#  <a class="board" href="/bbs/GBF/index.html">
#  <div class="board-name">GBF</div>
#  <div class="board-nuser"><span class="hl">113</span></div>
#  <div class="board-class">扮演</div>
#  <div class="board-title">◎[GBF] 六周年後夜祭%四格動畫化</div>
#  </a>,
#  <a class="board" href="/bbs/Zastrology/index.html">
#  <div class="board-name">Zastrology</div>
#  <div class="board-nuser"><span class="hl">113</span></div>
#  <div class="board-class">星座</div>
#  <div class="board-title">◎[星座] 十二星座  </div>
#  </a>,
#  <a class="board" href="/bbs/cat/index.html">
#  <div class="board-name">cat</div>
#  <div class="board-nuser"><span class="hl">109</span></div>
#  <div class="board-class">寵物</div>
#  <div class="board-title">◎喵板～</div>
#  </a>,
#  <a class="board" href="/bbs/KoreanPop/index.html">
#  <div class="board-name">KoreanPop</div>
#  <div class="board-nuser"><span class="hl">108</span></div>
#  <div class="board-class">音樂</div>
#  <div class="board-title">◎抵制買榜 抵制作弊，韓樂需要正義</div>
#  </a>,
#  <a class="board" href="/bbs/studyteacher/index.html">
#  <div class="board-name">studyteacher</div>
#  <div class="board-nuser"><span class="hl">108</span></div>
#  <div class="board-class">教師</div>
#  <div class="board-title">◎實習教師! 看板規!代理置底推!^0^</div>
#  </a>,
#  <a class="board" href="/bbs/PuzzleDragon/index.html">
#  <div class="board-name">PuzzleDragon</div>
#  <div class="board-nuser"><span class="hl">107</span></div>
#  <div class="board-class">拼圖</div>
#  <div class="board-title">◎[P＆D] 龍族拼圖</div>
#  </a>,
#  <a class="board" href="/bbs/give/index.html">
#  <div class="board-name">give</div>
#  <div class="board-nuser"><span class="hl">107</span></div>
#  <div class="board-class">贈送</div>
#  <div class="board-title">◎[贈送] 不合格式 砍文</div>
#  </a>,
#  <a class="board" href="/bbs/FATE_GO/index.html">
#  <div class="board-name">FATE_GO</div>
#  <div class="board-nuser"><span class="hl">100</span></div>
#  <div class="board-class">手遊</div>
#  <div class="board-title">◎[FGO] 日2-5下/美天竺/台森友會</div>
#  </a>,
#  <a class="board" href="/bbs/facelift/index.html">
#  <div class="board-name">facelift</div>
#  <div class="board-nuser"><span class="hl">97</span></div>
#  <div class="board-class">美容</div>
#  <div class="board-title">◎[醫學美容版]　嚴禁揪團買賣廣告</div>
#  </a>,
#  <a class="board" href="/bbs/DMM_GAMES/index.html">
#  <div class="board-name">DMM_GAMES</div>
#  <div class="board-nuser"><span class="hl">96</span></div>
#  <div class="board-class">遊戲</div>
#  <div class="board-title">◎[DMMG][千年] 魔神キメリエスLV16</div>
#  </a>,
#  <a class="board" href="/bbs/job/index.html">
#  <div class="board-name">job</div>
#  <div class="board-nuser"><span class="hl">96</span></div>
#  <div class="board-class">求職</div>
#  <div class="board-title">◎要求先提供照片 一律刪文水桶一週</div>
#  </a>,
#  <a class="board" href="/bbs/MobilePay/index.html">
#  <div class="board-name">MobilePay</div>
#  <div class="board-nuser"><span class="hl">95</span></div>
#  <div class="board-class">理財</div>
#  <div class="board-title">◎刷卡回饋問題請至信用卡板</div>
#  </a>,
#  <a class="board" href="/bbs/nb-shopping/index.html">
#  <div class="board-name">nb-shopping</div>
#  <div class="board-nuser"><span class="hl">94</span></div>
#  <div class="board-class">硬體</div>
#  <div class="board-title">◎請勿代買注意詐騙.買賣五天各一篇</div>
#  </a>,
#  <a class="board" href="/bbs/outdoorgear/index.html">
#  <div class="board-name">outdoorgear</div>
#  <div class="board-nuser"><span class="hl">92</span></div>
#  <div class="board-class">購二</div>
#  <div class="board-title">◎戶外裝備版</div>
#  </a>,
#  <a class="board" href="/bbs/PublicServan/index.html">
#  <div class="board-name">PublicServan</div>
#  <div class="board-nuser"><span class="hl">92</span></div>
#  <div class="board-class">公職</div>
#  <div class="board-title">◎[公職] 勤洗手戴口罩好防疫</div>
#  </a>,
#  <a class="board" href="/bbs/part-time/index.html">
#  <div class="board-name">part-time</div>
#  <div class="board-nuser"><span class="hl">92</span></div>
#  <div class="board-class">求職</div>
#  <div class="board-title">◎[打工] 民國109年1月1日起時薪158</div>
#  </a>,
#  <a class="board" href="/bbs/Military/index.html">
#  <div class="board-name">Military</div>
#  <div class="board-nuser"><span class="hl">92</span></div>
#  <div class="board-class">軍武</div>
#  <div class="board-title">◎冷靜與理性,純粹論軍武</div>
#  </a>,
#  <a class="board" href="/bbs/hypermall/index.html">
#  <div class="board-name">hypermall</div>
#  <div class="board-nuser"><span class="hl">90</span></div>
#  <div class="board-class">購三</div>
#  <div class="board-title">◎[賣場] 請勿哄搶物資 天佑台灣</div>
#  </a>,
#  <a class="board" href="/bbs/Bank_Service/index.html">
#  <div class="board-name">Bank_Service</div>
#  <div class="board-nuser"><span class="hl">90</span></div>
#  <div class="board-class">銀行</div>
#  <div class="board-title">◎[銀行服務板] 發文需滿50字及三行</div>
#  </a>,
#  <a class="board" href="/bbs/BabyProducts/index.html">
#  <div class="board-name">BabyProducts</div>
#  <div class="board-nuser"><span class="hl">88</span></div>
#  <div class="board-class">買賣</div>
#  <div class="board-title">◎[婦嬰買賣]依格式發文/禁止贈&amp;換</div>
#  </a>,
#  <a class="board" href="/bbs/BTS/index.html">
#  <div class="board-name">BTS</div>
#  <div class="board-nuser"><span class="hl">87</span></div>
#  <div class="board-class">韓國</div>
#  <div class="board-title">◎MAP OF THE SOUL : 7 </div>
#  </a>,
#  <a class="board" href="/bbs/TWICE/index.html">
#  <div class="board-name">TWICE</div>
#  <div class="board-nuser"><span class="hl">86</span></div>
#  <div class="board-class">韓國</div>
#  <div class="board-title">◎[TWICE] TIME TO TWICE</div>
#  </a>,
#  <a class="board" href="/bbs/Nogizaka46/index.html">
#  <div class="board-name">Nogizaka46</div>
#  <div class="board-nuser"><span class="hl">80</span></div>
#  <div class="board-class">日本</div>
#  <div class="board-title">◎25th「しあわせの保護色」発売中~</div>
#  </a>,
#  <a class="board" href="/bbs/points/index.html">
#  <div class="board-name">points</div>
#  <div class="board-nuser"><span class="hl">80</span></div>
#  <div class="board-class">旅遊</div>
#  <div class="board-title">◎點數哩程板 周一至五禁貼交易文</div>
#  </a>,
#  <a class="board" href="/bbs/HelpBuy/index.html">
#  <div class="board-name">HelpBuy</div>
#  <div class="board-nuser"><span class="hl">78</span></div>
#  <div class="board-class">買賣</div>
#  <div class="board-title">◎[代買] 暫時禁止徵求文及宣導</div>
#  </a>,
#  <a class="board" href="/bbs/BB-Love/index.html">
#  <div class="board-name">BB-Love</div>
#  <div class="board-nuser"><span class="hl">77</span></div>
#  <div class="board-class">屬性</div>
#  <div class="board-title">◎[絕愛] </div>
#  </a>,
#  <a class="board" href="/bbs/FTV/index.html">
#  <div class="board-name">FTV</div>
#  <div class="board-nuser"><span class="hl">76</span></div>
#  <div class="board-class">頻道</div>
#  <div class="board-title">◎[民視] 三泰又出手打如萍</div>
#  </a>,
#  <a class="board" href="/bbs/DSLR/index.html">
#  <div class="board-name">DSLR</div>
#  <div class="board-nuser"><span class="hl">74</span></div>
#  <div class="board-class">攝影</div>
#  <div class="board-title">◎[攝影]新手日在周日，歡迎作品</div>
#  </a>,
#  <a class="board" href="/bbs/FITNESS/index.html">
#  <div class="board-name">FITNESS</div>
#  <div class="board-nuser"><span class="hl">74</span></div>
#  <div class="board-class">美體</div>
#  <div class="board-title">◎[體適能] 徵人/轉讓文會被水桶7天</div>
#  </a>,
#  <a class="board" href="/bbs/APINK/index.html">
#  <div class="board-name">APINK</div>
#  <div class="board-nuser"><span class="hl">72</span></div>
#  <div class="board-class">韓國</div>
#  <div class="board-title">◎HappyNAMJOODay OurCEONamjooDay</div>
#  </a>,
#  <a class="board" href="/bbs/Teacher/index.html">
#  <div class="board-name">Teacher</div>
#  <div class="board-nuser"><span class="hl">72</span></div>
#  <div class="board-class">教師</div>
#  <div class="board-title">◎[踢雀] 仲春四月</div>
#  </a>,
#  <a class="board" href="/bbs/fastfood/index.html">
#  <div class="board-name">fastfood</div>
#  <div class="board-nuser"><span class="hl">71</span></div>
#  <div class="board-class">美食</div>
#  <div class="board-title">◎[速食] </div>
#  </a>,
#  <a class="board" href="/bbs/SET/index.html">
#  <div class="board-name">SET</div>
#  <div class="board-nuser"><span class="hl">71</span></div>
#  <div class="board-class">頻道</div>
#  <div class="board-title">◎[泣] 顛覆倫理 挑戰靈魂</div>
#  </a>,
#  <a class="board" href="/bbs/NBA_Film/index.html">
#  <div class="board-name">NBA_Film</div>
#  <div class="board-nuser"><span class="hl">71</span></div>
#  <div class="board-class">NBA.</div>
#  <div class="board-title">◎新賽季開始 請好好遵守板規</div>
#  </a>]

# %%
board_list = getPapularBoards()

# %%
[b for b in board_list]
# Out:
# ['Gossiping',
#  'Stock',
#  'C_Chat',
#  'Baseball',
#  'Lifeismoney',
#  'NBA',
#  'NSwitch',
#  'BabyMother',
#  'MobileComm',
#  'sex',
#  'Beauty',
#  'WomenTalk',
#  'car',
#  'LoL',
#  'Option',
#  'Boy-Girl',
#  'marriage',
#  'AnimalForest',
#  'Kaohsiung',
#  'PlayStation',
#  'Tech_Job',
#  'Tainan',
#  'HatePolitics',
#  'marvel',
#  'KoreaStar',
#  'movie',
#  'PC_Shopping',
#  'home-sale',
#  'joke',
#  'e-shopping',
#  'creditcard',
#  'AllTogether',
#  'KoreaDrama',
#  'iOS',
#  'CVS',
#  'CFantasy',
#  'Steam',
#  'japanavgirls',
#  'ToS',
#  'TaichungBun',
#  'Gamesale',
#  'HardwareSale',
#  'PCReDive',
#  'MakeUp',
#  'BeautySalon',
#  'EAseries',
#  'basketballTW',
#  'AC_In',
#  'StupidClown',
#  'Japandrama',
#  'PokemonGO',
#  'Hsinchu',
#  'Hearthstone',
#  'Soft_Job',
#  'MuscleBeach',
#  'biker',
#  'Salary',
#  'KR_Entertain',
#  'ONE_PIECE',
#  'mobilesales',
#  'CarShop',
#  'Japan_Travel',
#  'China-Drama',
#  'cat',
#  'BuyTogether',
#  'WOW',
#  'PuzzleDragon',
#  'GBF',
#  'PathofExile',
#  'part-time',
#  'Headphone',
#  'MH',
#  'Immigration',
#  'Bank_Service',
#  'Palmar_Drama',
#  'MobilePay',
#  'Brand',
#  'forsale',
#  'TW_Entertain',
#  'Wanted',
#  'Aviation',
#  'SuperBike',
#  'PublicServan',
#  'E-appliance',
#  'cookclub',
#  'YuanChuang',
#  'Finance',
#  'Gov_owned',
#  'watch',
#  'BB-Love',
#  'hypermall',
#  'DMM_GAMES',
#  'give',
#  'Elephants',
#  'BabyProducts',
#  'TaiwanDrama',
#  'studyabroad',
#  'Food',
#  'FATE_GO',
#  'graduate',
#  'Guardians',
#  'lesbian',
#  'TWICE',
#  'studyteacher',
#  'job',
#  'nb-shopping',
#  'Militarylife',
#  'gay',
#  'Nogizaka46',
#  'Examination',
#  'GetMarry',
#  'DC_SALE',
#  'SENIORHIGH',
#  'BigBanciao',
#  'Military',
#  'DSLR',
#  'ArenaOfValor',
#  'Foreign_Inv',
#  'Facebook',
#  'BTS',
#  'Key_Mou_Pad',
#  'FITNESS',
#  'ChangHua',
#  'Teacher',
#  'KoreanPop',
#  'MacShop',
#  'KanColle',
#  'Audiophile']

# %%
board_list
# Out:
# {'Gossiping': {'board_url': 'https://www.ptt.cc/bbs/Gossiping/index.html',
#   'board_title': '◎【八卦】版主投票開始囉！',
#   'board_class': '綜合'},
#  'Stock': {'board_url': 'https://www.ptt.cc/bbs/Stock/index.html',
#   'board_title': '◎3/30 0：00起 板規處分提高一級',
#   'board_class': '學術'},
#  'C_Chat': {'board_url': 'https://www.ptt.cc/bbs/C_Chat/index.html',
#   'board_title': '◎[希洽] 猶豫就會敗北',
#   'board_class': '閒談'},
#  'Baseball': {'board_url': 'https://www.ptt.cc/bbs/Baseball/index.html',
#   'board_title': '◎[棒球] 中職31年開幕',
#   'board_class': '棒球'},
#  'Lifeismoney': {'board_url': 'https://www.ptt.cc/bbs/Lifeismoney/index.html',
#   'board_title': '◎[省錢] 省錢板 請先看置底板規',
#   'board_class': '省錢'},
#  'NBA': {'board_url': 'https://www.ptt.cc/bbs/NBA/index.html',
#   'board_title': '◎[NBA] 球季無限期停賽',
#   'board_class': '籃球'},
#  'NSwitch': {'board_url': 'https://www.ptt.cc/bbs/NSwitch/index.html',
#   'board_title': '◎[NS] 重大投票公告詳置底',
#   'board_class': '主機'},
#  'BabyMother': {'board_url': 'https://www.ptt.cc/bbs/BabyMother/index.html',
#   'board_title': '◎[媽寶] 群組文僅限週四發表',
#   'board_class': '家庭'},
#  'MobileComm': {'board_url': 'https://www.ptt.cc/bbs/MobileComm/index.html',
#   'board_title': '◎[通訊] 入板前請先詳閱板規',
#   'board_class': '資訊'},
#  'sex': {'board_url': 'https://www.ptt.cc/bbs/sex/index.html',
#   'board_title': '◎[西斯] 勤洗手 戴口罩 再♡♥',
#   'board_class': '男女'},
#  'Beauty': {'board_url': 'https://www.ptt.cc/bbs/Beauty/index.html',
#   'board_title': '◎《表特板》發文附圖',
#   'board_class': '聊天'},
#  'WomenTalk': {'board_url': 'https://www.ptt.cc/bbs/WomenTalk/index.html',
#   'board_title': '◎[女孩] 勤洗手 戴口罩',
#   'board_class': '聊天'},
#  'car': {'board_url': 'https://www.ptt.cc/bbs/car/index.html',
#   'board_title': '◎[汽車] 發文必須滿30字',
#   'board_class': '車車'},
#  'LoL': {'board_url': 'https://www.ptt.cc/bbs/LoL/index.html',
#   'board_title': '◎[LoL] PCS今年MSI有望0敗',
#   'board_class': '遊戲'},
#  'Option': {'board_url': 'https://www.ptt.cc/bbs/Option/index.html',
#   'board_title': '◎[期權] 手續費洽broker板',
#   'board_class': '學術'},
#  'Boy-Girl': {'board_url': 'https://www.ptt.cc/bbs/Boy-Girl/index.html',
#   'board_title': '◎[男女] c2-政治 加重罰則',
#   'board_class': '心情'},
#  'marriage': {'board_url': 'https://www.ptt.cc/bbs/marriage/index.html',
#   'board_title': '◎板主徵求中',
#   'board_class': '婚姻'},
#  'AnimalForest': {'board_url': 'https://www.ptt.cc/bbs/AnimalForest/index.html',
#   'board_title': '◎[動森]動物森友會',
#   'board_class': '扮演'},
#  'Kaohsiung': {'board_url': 'https://www.ptt.cc/bbs/Kaohsiung/index.html',
#   'board_title': '◎[高雄]留心身體健康狀況 護人護己',
#   'board_class': '高雄'},
#  'PlayStation': {'board_url': 'https://www.ptt.cc/bbs/PlayStation/index.html',
#   'board_title': '◎[PS4] 4/15~4/28 PSN春季特賣!',
#   'board_class': '主機'},
#  'Tech_Job': {'board_url': 'https://www.ptt.cc/bbs/Tech_Job/index.html',
#   'board_title': '◎[科技] 修機改善是設備終生職責',
#   'board_class': '工作'},
#  'Tainan': {'board_url': 'https://www.ptt.cc/bbs/Tainan/index.html',
#   'board_title': '◎[台南] 置底有大台南活動整理',
#   'board_class': '台南'},
#  'HatePolitics': {'board_url': 'https://www.ptt.cc/bbs/HatePolitics/index.html',
#   'board_title': '◎[政黑] 小心病毒 做好防疫',
#   'board_class': 'Hate'},
#  'marvel': {'board_url': 'https://www.ptt.cc/bbs/marvel/index.html',
#   'board_title': '◎[媽佛] 諾亞方舟已開放登船囉!!!',
#   'board_class': '生二'},
#  'KoreaStar': {'board_url': 'https://www.ptt.cc/bbs/KoreaStar/index.html',
#   'board_title': '◎[韓星] 發/推文前請務必詳閱板規',
#   'board_class': '韓國'},
#  'movie': {'board_url': 'https://www.ptt.cc/bbs/movie/index.html',
#   'board_title': '◎[電影] 進場戴口罩 勤洗手 保平安',
#   'board_class': '綜合'},
#  'PC_Shopping': {'board_url': 'https://www.ptt.cc/bbs/PC_Shopping/index.html',
#   'board_title': '◎[電蝦] 出入公共場所記得自身防護',
#   'board_class': '硬體'},
#  'home-sale': {'board_url': 'https://www.ptt.cc/bbs/home-sale/index.html',
#   'board_title': '◎[房屋] 請勿張貼無關本板之新聞',
#   'board_class': '房屋'},
#  'joke': {'board_url': 'https://www.ptt.cc/bbs/joke/index.html',
#   'board_title': '◎[joke] 就可板',
#   'board_class': '娛樂'},
#  'e-shopping': {'board_url': 'https://www.ptt.cc/bbs/e-shopping/index.html',
#   'board_title': '◎[ＥＳ] 板主徵求中喔',
#   'board_class': '網購'},
#  'creditcard': {'board_url': 'https://www.ptt.cc/bbs/creditcard/index.html',
#   'board_title': '◎[信用卡] 新增[海外]分類範本',
#   'board_class': '理財'},
#  'AllTogether': {'board_url': 'https://www.ptt.cc/bbs/AllTogether/index.html',
#   'board_title': '◎[歐兔] 發文前詳閱置底板規&文摘',
#   'board_class': '聯誼'},
#  'KoreaDrama': {'board_url': 'https://www.ptt.cc/bbs/KoreaDrama/index.html',
#   'board_title': '◎[韓劇] 2019年度徵文活動ING',
#   'board_class': '韓劇'},
#  'iOS': {'board_url': 'https://www.ptt.cc/bbs/iOS/index.html',
#   'board_title': '◎[iOS] 嘿Siri 開啟妓院模式',
#   'board_class': '系統'},
#  'CVS': {'board_url': 'https://www.ptt.cc/bbs/CVS/index.html',
#   'board_title': '◎贈送文請移至專板 加強刪除週',
#   'board_class': '資訊'},
#  'CFantasy': {'board_url': 'https://www.ptt.cc/bbs/CFantasy/index.html',
#   'board_title': '◎[玄幻] 你掉的是分類還是20字心得',
#   'board_class': '玄幻'},
#  'Steam': {'board_url': 'https://www.ptt.cc/bbs/Steam/index.html',
#   'board_title': '◎本板禁止買賣合購代購代刷',
#   'board_class': '平台'},
#  'japanavgirls': {'board_url': 'https://www.ptt.cc/bbs/japanavgirls/index.html',
#   'board_title': '◎AV女優板 清新、優質,神人照格式',
#   'board_class': '綜合'},
#  'ToS': {'board_url': 'https://www.ptt.cc/bbs/ToS/index.html',
#   'board_title': '◎[神魔] 我起手就延遲',
#   'board_class': '轉珠'},
#  'TaichungBun': {'board_url': 'https://www.ptt.cc/bbs/TaichungBun/index.html',
#   'board_title': '◎[臺中] 戴口罩 勤洗手',
#   'board_class': '台中'},
#  'Gamesale': {'board_url': 'https://www.ptt.cc/bbs/Gamesale/index.html',
#   'board_title': '◎森友會健身環主機販售請附商品圖',
#   'board_class': '綜合'},
#  'HardwareSale': {'board_url': 'https://www.ptt.cc/bbs/HardwareSale/index.html',
#   'board_title': '◎[硬體買賣] 發文前請詳閱板規',
#   'board_class': '買賣'},
#  'PCReDive': {'board_url': 'https://www.ptt.cc/bbs/PCReDive/index.html',
#   'board_title': '◎[公連] 三號板工補選開跑',
#   'board_class': '手遊'},
#  'MakeUp': {'board_url': 'https://www.ptt.cc/bbs/MakeUp/index.html',
#   'board_title': '◎[美妝] 本板新增板主刪除推文功能',
#   'board_class': '美容'},
#  'BeautySalon': {'board_url': 'https://www.ptt.cc/bbs/BeautySalon/index.html',
#   'board_title': '◎[美保] 本板新增板主刪除推文功能',
#   'board_class': '美容'},
#  'EAseries': {'board_url': 'https://www.ptt.cc/bbs/EAseries/index.html',
#   'board_title': '◎[歐美影集] Stranger Things',
#   'board_class': '歐美'},
#  'basketballTW': {'board_url': 'https://www.ptt.cc/bbs/basketballTW/index.html',
#   'board_title': '◎台灣籃球',
#   'board_class': '籃球'},
#  'AC_In': {'board_url': 'https://www.ptt.cc/bbs/AC_In/index.html',
#   'board_title': '◎[裏洽] 勤洗手',
#   'board_class': '閒談'},
#  'StupidClown': {'board_url': 'https://www.ptt.cc/bbs/StupidClown/index.html',
#   'board_title': '◎ 哼哼哼哼',
#   'board_class': '經歷'},
#  'Japandrama': {'board_url': 'https://www.ptt.cc/bbs/Japandrama/index.html',
#   'board_title': '◎[日劇] 夏日22 ムロツヨシ',
#   'board_class': '日劇'},
#  'PokemonGO': {'board_url': 'https://www.ptt.cc/bbs/PokemonGO/index.html',
#   'board_title': '◎[PMGO] 凱西社群日 4/25',
#   'board_class': '抓寶'},
#  'Hsinchu': {'board_url': 'https://www.ptt.cc/bbs/Hsinchu/index.html',
#   'board_title': '◎[新竹] 口罩在哪裡!!',
#   'board_class': '新竹'},
#  'Hearthstone': {'board_url': 'https://www.ptt.cc/bbs/Hearthstone/index.html',
#   'board_title': '◎[爐石] 旅店大門永遠敞開著',
#   'board_class': '線上'},
#  'Soft_Job': {'board_url': 'https://www.ptt.cc/bbs/Soft_Job/index.html',
#   'board_title': '◎[軟工] 4/7~4/20 技術徵文投票',
#   'board_class': '工作'},
#  'MuscleBeach': {'board_url': 'https://www.ptt.cc/bbs/MuscleBeach/index.html',
#   'board_title': '◎[健身] 發文前請務必詳閱板規',
#   'board_class': '美體'},
#  'biker': {'board_url': 'https://www.ptt.cc/bbs/biker/index.html',
#   'board_title': '◎[Biker] 都是車、別分那麼細(?',
#   'board_class': '車車'},
#  'Salary': {'board_url': 'https://www.ptt.cc/bbs/Salary/index.html',
#   'board_title': '◎[職場] 工作職場板',
#   'board_class': '職場'},
#  'KR_Entertain': {'board_url': 'https://www.ptt.cc/bbs/KR_Entertain/index.html',
#   'board_title': '◎[韓綜] Show Me The 新板主!',
#   'board_class': '綜藝'},
#  'ONE_PIECE': {'board_url': 'https://www.ptt.cc/bbs/ONE_PIECE/index.html',
#   'board_title': '◎[海賊王]    977 宴會不開了',
#   'board_class': '日本'},
#  'mobilesales': {'board_url': 'https://www.ptt.cc/bbs/mobilesales/index.html',
#   'board_title': '◎☆面交☆ 別貪小便宜!小心詐騙!',
#   'board_class': '資訊'},
#  'CarShop': {'board_url': 'https://www.ptt.cc/bbs/CarShop/index.html',
#   'board_title': '◎[汽車買賣] 不懂就發文前先問板主',
#   'board_class': '買賣'},
#  'Japan_Travel': {'board_url': 'https://www.ptt.cc/bbs/Japan_Travel/index.html',
#   'board_title': '◎日本緊急事態宣言 請暫緩出國計畫',
#   'board_class': '旅遊'},
#  'China-Drama': {'board_url': 'https://www.ptt.cc/bbs/China-Drama/index.html',
#   'board_title': '◎[陸劇] 歡迎收看戲說如懿',
#   'board_class': '陸劇'},
#  'cat': {'board_url': 'https://www.ptt.cc/bbs/cat/index.html',
#   'board_title': '◎喵板～',
#   'board_class': '寵物'},
#  'BuyTogether': {'board_url': 'https://www.ptt.cc/bbs/BuyTogether/index.html',
#   'board_title': '◎[合購] 注意疫情 勤洗手最重要',
#   'board_class': '買賣'},
#  'WOW': {'board_url': 'https://www.ptt.cc/bbs/WOW/index.html',
#   'board_title': '◎[WoW] 在家練等就是最好的防疫',
#   'board_class': '線上'},
#  'PuzzleDragon': {'board_url': 'https://www.ptt.cc/bbs/PuzzleDragon/index.html',
#   'board_title': '◎[P＆D] 龍族拼圖',
#   'board_class': '拼圖'},
#  'GBF': {'board_url': 'https://www.ptt.cc/bbs/GBF/index.html',
#   'board_title': '◎[GBF] R.I.P. 歐根大叔',
#   'board_class': '扮演'},
#  'PathofExile': {'board_url': 'https://www.ptt.cc/bbs/PathofExile/index.html',
#   'board_title': '◎[PoE] 開季自主隔離14天',
#   'board_class': '線上'},
#  'part-time': {'board_url': 'https://www.ptt.cc/bbs/part-time/index.html',
#   'board_title': '◎[打工] 民國109年1月1日起時薪158',
#   'board_class': '求職'},
#  'Headphone': {'board_url': 'https://www.ptt.cc/bbs/Headphone/index.html',
#   'board_title': '◎溫馨耳機板 心得文請多加敘述聽感',
#   'board_class': '資訊'},
#  'MH': {'board_url': 'https://www.ptt.cc/bbs/MH/index.html',
#   'board_title': '◎[MH] M級絢輝與煌黑龍即將登場',
#   'board_class': '狩獵'},
#  'Immigration': {'board_url': 'https://www.ptt.cc/bbs/Immigration/index.html',
#   'board_title': '◎各國移民事務板',
#   'board_class': '旅遊'},
#  'Bank_Service': {'board_url': 'https://www.ptt.cc/bbs/Bank_Service/index.html',
#   'board_title': '◎[銀行服務板] 發文需滿50字及三行',
#   'board_class': '銀行'},
#  'Palmar_Drama': {'board_url': 'https://www.ptt.cc/bbs/Palmar_Drama/index.html',
#   'board_title': '◎穿個界看到白髮旋渦眉',
#   'board_class': '布袋'},
#  'MobilePay': {'board_url': 'https://www.ptt.cc/bbs/MobilePay/index.html',
#   'board_title': '◎刷卡回饋問題請至信用卡板',
#   'board_class': '理財'},
#  'Brand': {'board_url': 'https://www.ptt.cc/bbs/Brand/index.html',
#   'board_title': '◎   ＊* 布蘭德 細節的價值 ＊*',
#   'board_class': '資訊'},
#  'forsale': {'board_url': 'https://www.ptt.cc/bbs/forsale/index.html',
#   'board_title': '◎[跳蚤] 木反 夫見 彳艮 日月 目尞',
#   'board_class': '市場'},
#  'TW_Entertain': {'board_url': 'https://www.ptt.cc/bbs/TW_Entertain/index.html',
#   'board_title': '◎[台綜] 可唯哪~~~',
#   'board_class': '綜藝'},
#  'Wanted': {'board_url': 'https://www.ptt.cc/bbs/Wanted/index.html',
#   'board_title': '◎[汪踢] 新板主準備上任',
#   'board_class': '徵求'},
#  'Aviation': {'board_url': 'https://www.ptt.cc/bbs/Aviation/index.html',
#   'board_title': '◎[航空] 航空板/請用退票分類諮詢',
#   'board_class': '交通'},
#  'SuperBike': {'board_url': 'https://www.ptt.cc/bbs/SuperBike/index.html',
#   'board_title': '◎PTT重機板~安全是唯一回家的路',
#   'board_class': '車車'},
#  'PublicServan': {'board_url': 'https://www.ptt.cc/bbs/PublicServan/index.html',
#   'board_title': '◎[公職] 勤洗手戴口罩好防疫',
#   'board_class': '公職'},
#  'E-appliance': {'board_url': 'https://www.ptt.cc/bbs/E-appliance/index.html',
#   'board_title': '◎[家電] 冷氣文未照內建格式寫會刪',
#   'board_class': '資訊'},
#  'cookclub': {'board_url': 'https://www.ptt.cc/bbs/cookclub/index.html',
#   'board_title': '◎歡迎分享手做美食',
#   'board_class': '烹飪'},
#  'YuanChuang': {'board_url': 'https://www.ptt.cc/bbs/YuanChuang/index.html',
#   'board_title': '◎[原創] 年度必看投票: 提名中！',
#   'board_class': '原創'},
#  'Finance': {'board_url': 'https://www.ptt.cc/bbs/Finance/index.html',
#   'board_title': '◎金融業板 你買金管會正二了嗎?',
#   'board_class': '金融'},
#  'Gov_owned': {'board_url': 'https://www.ptt.cc/bbs/Gov_owned/index.html',
#   'board_title': '◎[國營] 勤洗手戴口罩好防疫',
#   'board_class': '國營'},
#  'watch': {'board_url': 'https://www.ptt.cc/bbs/watch/index.html',
#   'board_title': '◎[錶板] Show me your Watch!',
#   'board_class': '購一'},
#  'BB-Love': {'board_url': 'https://www.ptt.cc/bbs/BB-Love/index.html',
#   'board_title': '◎[絕愛] ',
#   'board_class': '屬性'},
#  'hypermall': {'board_url': 'https://www.ptt.cc/bbs/hypermall/index.html',
#   'board_title': '◎[賣場] 請勿哄搶物資 天佑台灣',
#   'board_class': '購三'},
#  'DMM_GAMES': {'board_url': 'https://www.ptt.cc/bbs/DMM_GAMES/index.html',
#   'board_title': '◎[DMMG] 飯渣這樣不好',
#   'board_class': '遊戲'},
#  'give': {'board_url': 'https://www.ptt.cc/bbs/give/index.html',
#   'board_title': '◎[贈送] 不合格式 砍文',
#   'board_class': '贈送'},
#  'Elephants': {'board_url': 'https://www.ptt.cc/bbs/Elephants/index.html',
#   'board_title': '◎只能看轉播的日子',
#   'board_class': 'CPBL'},
#  'BabyProducts': {'board_url': 'https://www.ptt.cc/bbs/BabyProducts/index.html',
#   'board_title': '◎[婦嬰買賣]依格式發文/禁止贈&換',
#   'board_class': '買賣'},
#  'TaiwanDrama': {'board_url': 'https://www.ptt.cc/bbs/TaiwanDrama/index.html',
#   'board_title': '◎[臺劇] 李國毅《金愛演真探團》',
#   'board_class': '臺劇'},
#  'studyabroad': {'board_url': 'https://www.ptt.cc/bbs/studyabroad/index.html',
#   'board_title': '◎[留學] 請大家注意身體健康',
#   'board_class': '留學'},
#  'Food': {'board_url': 'https://www.ptt.cc/bbs/Food/index.html',
#   'board_title': '◎美食板',
#   'board_class': '美食'},
#  'FATE_GO': {'board_url': 'https://www.ptt.cc/bbs/FATE_GO/index.html',
#   'board_title': '◎[FGO] 日草地 / 美草地 / 台雨林',
#   'board_class': '手遊'},
#  'graduate': {'board_url': 'https://www.ptt.cc/bbs/graduate/index.html',
#   'board_title': '◎[研所] ',
#   'board_class': '研究'},
#  'Guardians': {'board_url': 'https://www.ptt.cc/bbs/Guardians/index.html',
#   'board_title': "◎It's Time",
#   'board_class': 'CPBL'},
#  'lesbian': {'board_url': 'https://www.ptt.cc/bbs/lesbian/index.html',
#   'board_title': '◎[拉板] 洗手 口罩 顧健康',
#   'board_class': '男女'},
#  'TWICE': {'board_url': 'https://www.ptt.cc/bbs/TWICE/index.html',
#   'board_title': '◎[TWICE] TIME TO TWICE',
#   'board_class': '韓國'},
#  'studyteacher': {'board_url': 'https://www.ptt.cc/bbs/studyteacher/index.html',
#   'board_title': '◎實習教師! 看板規!代理置底推!^0^',
#   'board_class': '教師'},
#  'job': {'board_url': 'https://www.ptt.cc/bbs/job/index.html',
#   'board_title': '◎要求先提供照片 一律刪文水桶一週',
#   'board_class': '求職'},
#  'nb-shopping': {'board_url': 'https://www.ptt.cc/bbs/nb-shopping/index.html',
#   'board_title': '◎請勿代買注意詐騙.買賣五天各一篇',
#   'board_class': '硬體'},
#  'Militarylife': {'board_url': 'https://www.ptt.cc/bbs/Militarylife/index.html',
#   'board_title': '◎[軍旅] 向黑鷹殉職軍官敬禮!!!',
#   'board_class': '軍旅'},
#  'gay': {'board_url': 'https://www.ptt.cc/bbs/gay/index.html',
#   'board_title': '◎[甲板]勤洗手戴口罩,防疫優先',
#   'board_class': '男女'},
#  'Nogizaka46': {'board_url': 'https://www.ptt.cc/bbs/Nogizaka46/index.html',
#   'board_title': '◎25th「しあわせの保護色」発売中~',
#   'board_class': '日本'},
#  'Examination': {'board_url': 'https://www.ptt.cc/bbs/Examination/index.html',
#   'board_title': '◎[國考] 勤洗手戴口罩好防疫',
#   'board_class': '考試'},
#  'GetMarry': {'board_url': 'https://www.ptt.cc/bbs/GetMarry/index.html',
#   'board_title': '◎Getmarry-廣宣週三、交易週日',
#   'board_class': '結婚'},
#  'DC_SALE': {'board_url': 'https://www.ptt.cc/bbs/DC_SALE/index.html',
#   'board_title': '◎數位相機交易 - 注意詐騙',
#   'board_class': '攝影'},
#  'SENIORHIGH': {'board_url': 'https://www.ptt.cc/bbs/SENIORHIGH/index.html',
#   'board_title': '◎[高中] 預備二階申請/徵文活動',
#   'board_class': '高中'},
#  'BigBanciao': {'board_url': 'https://www.ptt.cc/bbs/BigBanciao/index.html',
#   'board_title': '◎[板橋] 這裡是板橋~ 板橋板',
#   'board_class': '新北'},
#  'Military': {'board_url': 'https://www.ptt.cc/bbs/Military/index.html',
#   'board_title': '◎冷靜與理性,純粹論軍武',
#   'board_class': '軍武'},
#  'DSLR': {'board_url': 'https://www.ptt.cc/bbs/DSLR/index.html',
#   'board_title': '◎[攝影]新手日在周日，歡迎作品',
#   'board_class': '攝影'},
#  'ArenaOfValor': {'board_url': 'https://www.ptt.cc/bbs/ArenaOfValor/index.html',
#   'board_title': '◎傳說對決 板規2.0',
#   'board_class': '競技'},
#  'Foreign_Inv': {'board_url': 'https://www.ptt.cc/bbs/Foreign_Inv/index.html',
#   'board_title': '◎海外投資版',
#   'board_class': '理財'},
#  'Facebook': {'board_url': 'https://www.ptt.cc/bbs/Facebook/index.html',
#   'board_title': '◎[臉書] https://www.facebook.com',
#   'board_class': '生活'},
#  'BTS': {'board_url': 'https://www.ptt.cc/bbs/BTS/index.html',
#   'board_title': '◎ 板主徵求中喔喔',
#   'board_class': '韓國'},
#  'Key_Mou_Pad': {'board_url': 'https://www.ptt.cc/bbs/Key_Mou_Pad/index.html',
#   'board_title': '◎[鍵鼠] 鍵盤有沐浴乳的味道(?',
#   'board_class': '生活'},
#  'FITNESS': {'board_url': 'https://www.ptt.cc/bbs/FITNESS/index.html',
#   'board_title': '◎[體適能] 徵人/轉讓文會被水桶7天',
#   'board_class': '美體'},
#  'ChangHua': {'board_url': 'https://www.ptt.cc/bbs/ChangHua/index.html',
#   'board_title': '◎[彰化] 守護彰化 嚴防豬瘟+肺炎',
#   'board_class': '彰化'},
#  'Teacher': {'board_url': 'https://www.ptt.cc/bbs/Teacher/index.html',
#   'board_title': '◎[踢雀] 仲春四月',
#   'board_class': '教師'},
#  'KoreanPop': {'board_url': 'https://www.ptt.cc/bbs/KoreanPop/index.html',
#   'board_title': '◎抵制買榜 抵制作弊，韓樂需要正義',
#   'board_class': '音樂'},
#  'MacShop': {'board_url': 'https://www.ptt.cc/bbs/MacShop/index.html',
#   'board_title': '◎板主徵選/禁止發文中/唯讀',
#   'board_class': '資訊'},
#  'KanColle': {'board_url': 'https://www.ptt.cc/bbs/KanColle/index.html',
#   'board_title': '◎[艦娘] 真的有開出2號砲耶',
#   'board_class': '艦娘'},
#  'Audiophile': {'board_url': 'https://www.ptt.cc/bbs/Audiophile/index.html',
#   'board_title': '◎電腦喇叭 音響系統討論板~',
#   'board_class': '資訊'}}
