# %%
#!/usr/bin/env python
# coding: utf-8
'''
To inser date into database PTTDB.

insertIntoPttArticle( input_data: List[List[str]] ) -> effected_rows: int

insertIntoPttComment( input_data: List[List[str]] ) -> effected_rows: int

getAllArticleId() -> List[str]

getAllArticleIdInOneBoard( board_name: str ) -> articles_id: List[str]
'''
import pymysql
import json
import datetime

# Load the parameters for db connection
with open('./db.conf', 'r', encoding='utf-8') as f:
    dbconf = json.loads(f.read())

def insertIntoPttArticle(insert_data):
    
    TABLE_NAME = """PTT_ARTICLE"""
      
    COLUMNS_STR = """
    `title` VARCHAR(60) NOT NULL COMMENT '文章標題',
    `boardName` VARCHAR(40) COMMENT '看板名稱',
    `articleId` VARCHAR(45) NOT NULL COMMENT '文章編號',
    `authorId` VARCHAR(40) NOT NULL,
    `authorName` VARCHAR(45) NULL DEFAULT NULL,
    `publishedTime` TIMESTAMP NOT NULL COMMENT '文章發佈時間戳記',
    `canonicalUrl` VARCHAR(100) NOT NULL COMMENT '文章URL',
    `createdTime` DATETIME NOT NULL,
    `updateTime` DATETIME NOT NULL,
    `pushUp` INT NOT NULL COMMENT '文章推數',
    `pushDown` INT NOT NULL COMMENT '文章噓數',
    `content` TEXT NULL DEFAULT NULL COMMENT '文章內容',
    `commentContent` TEXT NULL DEFAULT NULL COMMENT '留言內容',"""
    
    COLUMNS_LIST = [r.strip(' ').replace('`', '').split(' ')[0] for r in COLUMNS_STR.split('\n') if r != '']
    COLUMNS = ', '.join(COLUMNS_LIST)
    COLUMNS_FORMAT = ", ".join(['%s' for i in COLUMNS_LIST])
    
    sql = "INSERT INTO {} ({}) VALUES ({})".format(TABLE_NAME, COLUMNS, COLUMNS_FORMAT)
    try:
        conn = pymysql.connect(**dbconf)
        print('Successfully connected!')
    except:
        return 0
    try:
        cursor = conn.cursor()
        effected_rows = cursor.executemany(sql, insert_data)
    #     cursor.execute(sql, insert_data)
    except:
        effected_rows = 0
    finally:
        cursor.close()
        conn.commit()
        conn.close()
    return effected_rows

def insertIntoPttComment(insert_data):
    
    TABLE_NAME = """PTT_COMMENT"""
      
    COLUMNS_STR = """
    `articleId` VARCHAR(45) NOT NULL COMMENT '文章編號',
    `commentId` VARCHAR(45) NOT NULL COMMENT '留言者ID',
    `commentContent` VARCHAR(100) NULL COMMENT '留言內容',
    `commentTime` TIMESTAMP NULL COMMENT '留言時間')"""

    COLUMNS_LIST = [r.strip(' ').replace('`', '').split(' ')[0] for r in COLUMNS_STR.split('\n') if r != '']
    COLUMNS = ', '.join(COLUMNS_LIST)
    COLUMNS_FORMAT = ", ".join(['%s' for i in COLUMNS_LIST])
    
    sql = "INSERT INTO {} ({}) VALUES ({})".format(TABLE_NAME, COLUMNS, COLUMNS_FORMAT)
    
    try:
        conn = pymysql.connect(**dbconf)
        print('Successfully connected!')
    except:
        return 0
    try:
        cursor = conn.cursor()
        effected_rows = cursor.executemany(sql, insert_data)
    except:
        effected_rows = 0
    finally:
        conn.commit()
        cursor.close()
        conn.close()
    return effected_rows

def getAllArticleId():
    sql = """SELECT articleId FROM PTT_ARTICLE;"""
    
    try:
        conn = pymysql.connect(**dbconf)
        print('Successfully connected!')
    except:
        return 0
    cursor = conn.cursor()
    
    cursor.execute(sql)
    articles_id = [id[0] for id in cursor.fetchall()]
    
    conn.commit()
    cursor.close()
    conn.close()
    return articles_id

def getAllArticleIdInOneBoard(board_name):
    sql = """SELECT articleId FROM PTT_ARTICLE WHERE boardName = '{}';""".format(board_name)
    
    try:
        conn = pymysql.connect(**dbconf)
        print('Successfully connected!')
    except:
        return 0
    cursor = conn.cursor()
    
    cursor.execute(sql)
    articles_id = [id[0] for id in cursor.fetchall()]
    
    conn.commit()
    cursor.close()
    conn.close()
    return articles_id

# %%
conn.commit()
# 關閉遊標
cursor.close()
# 關閉連線
conn.close()

# %%
import pymysql

host = 'db'
port = 3306
user = 'pttuser1'
passwd = 'howdoyouturnthison3306'
db = 'PTTDB'
charset = 'utf8mb4'

conn = pymysql.connect(host=host, port=port, user=user, passwd=passwd, db=db, charset=charset)
print('Successfully connected!')
# 建立遊標, 查詢資料預設為元組型別
cursor = conn.cursor()
# 執行SQL，並返回收影響行數
# row1 = cursor.execute("update users set password = '123'")
# print(row1)
# 執行SQL，並返回受影響行數
# row2 = cursor.execute("update users set password = '456' where id > %s", (1,))
# print(row2)
# 執行SQL，並返回受影響行數（使用pymysql的引數化語句防止SQL隱碼攻擊）
# row3 = cursor.executemany("insert into users(username, password, email)values(%s, %s, %s)", [("ceshi3", '333', 'ceshi3@11.com'), ("ceshi4", '444', 'ceshi4@qq.com')])
# print(row3)
# 提交，不然無法儲存新建或者修改的資料
# conn.commit()
# 關閉遊標
# cursor.close()
# 關閉連線
# conn.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f612bebb8849> in <module>
#       8 charset = 'utf8mb4'
#       9
# ---> 10 conn = pymysql.connect(host=host, port=port, user=user, passwd=passwd, db=db, charset=charset)
#      11 print('Successfully connected!')
#      12 # 建立遊標, 查詢資料預設為元組型別
#
# /opt/conda/lib/python3.7/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# ...

# %%
with open('./db.conf', 'r', encoding='utf-8') as f:
    dbconf = json.loads(f.read())
# Out:
# {'host': 'db',
#  'port': 3306,
#  'user': 'pttuser1',
#  'passwd': 'howdoyouturnthison3306',
#  'db': 'PTTDB',
#  'charset': 'utf8mb4'}

# %%
import pymysql

# 設定資料庫連線資訊
host = '127.0.0.1'
port = 3306
user = 'root'
passwd = 'root'
db = 'PTTDB'
charset = 'utf8mb4'

# 建立連線
conn = pymysql.connect(host=host, port=port, user=user, passwd=passwd, db=db, charset=charset)

# 建立遊標, 查詢資料預設為元組型別
cursor = conn.cursor()

# %%
TABLE_NAME = """`PTTDB`.`PTT_ARTICLE`"""

COLUMNS_STR = """
`title` VARCHAR(60) NOT NULL COMMENT '文章標題',
`boardName` VARCHAR(40) COMMENT '看板名稱',
`articleId` VARCHAR(45) NOT NULL COMMENT '文章編號',
`authorId` VARCHAR(40) NOT NULL,
`authorName` VARCHAR(45) NULL DEFAULT NULL,
`publishedTime` TIMESTAMP NOT NULL COMMENT '文章發佈時間戳記',
`canonicalUrl` VARCHAR(100) NOT NULL COMMENT '文章URL',
`createdTime` DATETIME NOT NULL,
`updateTime` DATETIME NOT NULL,
`pushUp` INT NOT NULL COMMENT '文章推數',
`pushDown` INT NOT NULL COMMENT '文章噓數',
`content` TEXT NULL DEFAULT NULL COMMENT '文章內容',
`commentContent` TEXT NULL DEFAULT NULL COMMENT '留言內容',"""

COLUMNS_LIST = [r.strip(' ').replace('`', '').split(' ')[0] for r in COLUMNS_STR.split('\n') if r != '']
COLUMNS = ', '.join(COLUMNS_LIST)
COLUMNS_FORMAT = ", ".join(["'%s'" for i in COLUMNS_LIST])

sql = "INSERT INTO {} ({}) VALUES ({})".format(TABLE_NAME, COLUMNS, COLUMNS_FORMAT)
sql
# Out:
# "INSERT INTO `PTTDB`.`PTT_ARTICLE` (title, boardName, articleId, authorId, authorName, publishedTime, canonicalUrl, createdTime, updateTime, pushUp, pushDown, content, commentContent) VALUES ('%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s')"

# %%
import datetime
insertData = [{'article_url': 'https://www.ptt.cc/bbs/Gossiping/M.1587091888.A.2E8.html',
  'auth_id': 'SakuraYui',
  'auth_name': '櫻花蝦',
  'title': '[新聞] 超車自撞牽拖別人竟連孕婦都打！9屁孩國',
  'date': datetime.datetime(2020, 4, 17, 10, 51, 25),
  'board_name': 'Gossiping',
  'article_content': '\n※新聞內容含有政治人物、政府機關類、政治族群類請以[政治]為分類，違者刪除!\n1.媒體來源:\n※ 例如蘋果日報、自由時報（請參考版規下方的核准媒體名單）\nettoday\n\n2.記者署名\n※ 沒有在這打上記者署名的新聞會被水桶14天 編輯非記者\n※ 外電至少要有來源或編輯 如:法新社\n徐愷昕\n\n3.完整新聞標題:\n※ 標題沒有完整寫出來 ---> 依照板規刪除文章\n超車自撞牽拖別人竟連孕婦都打！9屁孩國道逼車包抄無辜\u3000球棒狠K下場曝\n\n4.完整新聞內文:\n※ 社論特稿都不能貼！違者刪除（政治類水桶3個月)，貼廣告也會被刪除喔！可詳看版規\n\n記者徐愷昕／南投報導\n\n15名年輕人2017年7月相約墾丁旅遊，一行人北返回家途中行經國道3號南投路段時，4部\n車中的其中1部車為超越1輛紅色廂型車，不甚自撞護欄急停，怎料又遭後方來車撞上。超\n車自撞男子的同行友人誤以為是箱型車蛇行致車禍發生，竟集結其他3車在國道上高速逼\n車、倒車、逆向行駛，包抄砸車攻擊廂型車上的駕駛及乘客。南投地院依妨害公眾往來安\n全罪，判處釀禍的9人各3至9月有期徒刑。可上訴。\n\n2017年7月間一群20多歲年輕人開著4部車南下墾丁遊玩，旅程結束北上返家途中，在行經\n國道3號226.8K南投路段時，徐姓男子駕駛的車輛因想超越前方紅色廂型車，怎料過程中\n竟失控擦撞護欄急停在中線車道間，隨後又被後方轎車迎面硬生撞上。\n\n因超車差點受波及的紅色廂型車駕駛見事故發生，上前搖下車窗詢問自撞的徐男有無狀況\n後，見他無礙便隨即離開事故現場。此時整群年輕人的其他3部車，誤以為是紅色廂型車\n蛇行導致事故發生，但卻像沒事一樣直接離開，氣的迅速集結一塊，一同開車衝上前替朋\n友出氣。\n\n為了能攔下紅色箱型車，3車除了在國道高速逼車外，還各種倒車、逆向行駛，且在成功\n包抄後，更直接拿出球棒敲擊廂型車，將廂型車上1名駕駛及2名男乘客打傷，另還有1名\n孕婦也輕傷受驚嚇，全送醫治療。\n\n南投地院審理時認為，許姓等9名年輕人明知國道3號速限110公里，車速非常快速下一個\n不小心就可能造成重大事故發生，但他們卻僅因行車糾紛，就在深夜視線不佳的時候，不\n顧他人生命、身體安全，在國道上高速逼車、倒車、逆向行駛佔據道路，甚至還暴力砸車\n打人，審結依共同犯妨害公眾往來安全罪，判10名年輕人各3月到9月不等有期徒刑。可上\n訴。\n\n5.完整新聞連結 (或短網址):\n※ 當新聞連結過長時，需提供短網址方便網友點擊\nhttps://www.ettoday.net/news/20200417/1693571.htm\n\n6.備註:\n※ 一個人一天只能張貼一則新聞，被刪或自刪也算額度內，超貼者水桶，請注意\n\n--\n',
  'comment_content': [{'push-tag': '推 ',
    'push-userid': 'a1ibooda',
    'push-content': ': 可上訴？',
    'push-ipdatetime': ' 04/17 10:52'},
   {'push-tag': '推 ',
    'push-userid': 'peiring',
    'push-content': ': 台男',
    'push-ipdatetime': ' 04/17 10:52'},
   {'push-tag': '推 ',
    'push-userid': 'zoeapezoo',
    'push-content': ': 有教化可能',
    'push-ipdatetime': ' 04/17 10:52'},
   {'push-tag': '推 ',
    'push-userid': 'mouz',
    'push-content': ': 可以上國道的四輪不會這麼調皮，這些都是重機騎士偷開車，',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '→ ',
    'push-userid': 'mouz',
    'push-content': ': 重機不意外',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '推 ',
    'push-userid': 'fantasy15',
    'push-content': ': 3-9 個月..哈哈哈',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '噓 ',
    'push-userid': 'bc015128',
    'push-content': ': 重機不意外= =飆車就算了還攔車打人',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '→ ',
    'push-userid': 'bamama56',
    'push-content': ': 人渣判超輕 真爽',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '→ ',
    'push-userid': 'flarecutter',
    'push-content': ': 這要是我根本不會問他有沒有事 放他在路上等死',
    'push-ipdatetime': ' 04/17 10:54'},
   {'push-tag': '推 ',
    'push-userid': 'hikari22',
    'push-content': ': 屁孩背前科嘍舒服',
    'push-ipdatetime': ' 04/17 10:54'},
   {'push-tag': '推 ',
    'push-userid': 'randykaku',
    'push-content': ': 這種在黑道都是最低等級免洗筷的 不具備智慧的那種',
    'push-ipdatetime': ' 04/17 10:54'},
   {'push-tag': '推 ',
    'push-userid': 'awaken',
    'push-content': ': 犯這麼多條才這樣，是用了折價券喔？',
    'push-ipdatetime': ' 04/17 10:54'},
   {'push-tag': '→ ',
    'push-userid': 'hamasakiayu',
    'push-content': ': 3-9個月？是未成年嗎？',
    'push-ipdatetime': ' 04/17 10:54'},
   {'push-tag': '推 ',
    'push-userid': 'walter0914',
    'push-content': ': 真的有病',
    'push-ipdatetime': ' 04/17 10:54'},
   {'push-tag': '→ ',
    'push-userid': 'NTULioner',
    'push-content': ': 才3-9月',
    'push-ipdatetime': ' 04/17 10:54'},
   {'push-tag': '噓 ',
    'push-userid': 'XperiaZ6C',
    'push-content': ': 3-9個月是夏令營嗎',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '→ ',
    'push-userid': 'NTULioner',
    'push-content': ': 直接死刑比較快',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '噓 ',
    'push-userid': 'palapalanhu',
    'push-content': ': 台男',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '噓 ',
    'push-userid': 'cms6384',
    'push-content': ': 進監獄會不會屁眼開花勒',
    'push-ipdatetime': ' 04/17 10:56'},
   {'push-tag': '推 ',
    'push-userid': 'd22426539',
    'push-content': ': 人渣保護人渣很正常 我不是說義氣是說司法',
    'push-ipdatetime': ' 04/17 10:57'},
   {'push-tag': '推 ',
    'push-userid': 'godbar',
    'push-content': ': 3-9個月 根本不痛不癢 這種人渣也沒在怕前科拉 搞不好還會',
    'push-ipdatetime': ' 04/17 10:57'},
   {'push-tag': '→ ',
    'push-userid': 'godbar',
    'push-content': ': 拿出來炫耀說嘴',
    'push-ipdatetime': ' 04/17 10:57'},
   {'push-tag': '推 ',
    'push-userid': 'killerken',
    'push-content': ': 關3個月只是給這些8+9吹噓一輩子而已吧',
    'push-ipdatetime': ' 04/17 10:57'},
   {'push-tag': '推 ',
    'push-userid': 'ghgn',
    'push-content': ': 8+9',
    'push-ipdatetime': ' 04/17 10:57'},
   {'push-tag': '→ ',
    'push-userid': 'jobchung',
    'push-content': ': 統統敝掉',
    'push-ipdatetime': ' 04/17 10:58'},
   {'push-tag': '噓 ',
    'push-userid': 'vm03vm03',
    'push-content': ': 才九個月',
    'push-ipdatetime': ' 04/17 10:58'},
   {'push-tag': '噓 ',
    'push-userid': 'downgoon',
    'push-content': ': 這種咖小關三年還差不多',
    'push-ipdatetime': ' 04/17 10:59'},
   {'push-tag': '噓 ',
    'push-userid': 'dscndg',
    'push-content': ': 太輕',
    'push-ipdatetime': ' 04/17 11:00'},
   {'push-tag': '推 ',
    'push-userid': 'henryeech',
    'push-content': ': 殺人未遂才3-9月',
    'push-ipdatetime': ' 04/17 11:03'},
   {'push-tag': '推 ',
    'push-userid': 'aussieoz',
    'push-content': ': 判這麼輕？？法官到底在想什麼',
    'push-ipdatetime': ' 04/17 11:04'},
   {'push-tag': '噓 ',
    'push-userid': 'dcoog7880',
    'push-content': ': 才判這麼輕',
    'push-ipdatetime': ' 04/17 11:06'},
   {'push-tag': '噓 ',
    'push-userid': 'jeffky',
    'push-content': ': 太輕',
    'push-ipdatetime': ' 04/17 11:07'},
   {'push-tag': '推 ',
    'push-userid': 'b93510015',
    'push-content': ': 真的判夠輕，台灣司法有夠爛的',
    'push-ipdatetime': ' 04/17 11:09'},
   {'push-tag': '噓 ',
    'push-userid': 'JamesForrest',
    'push-content': ': 這什麼罪？告傷害也沒有這麼輕吧？檢察官是在？',
    'push-ipdatetime': ' 04/17 11:10'},
   {'push-tag': '推 ',
    'push-userid': 'turncolan',
    'push-content': ': 要是抄到法官家人就3~9年了',
    'push-ipdatetime': ' 04/17 11:11'},
   {'push-tag': '噓 ',
    'push-userid': 'ChildX',
    'push-content': ': 人渣還上訴 訴個爛叫啦',
    'push-ipdatetime': ' 04/17 11:12'},
   {'push-tag': '→ ',
    'push-userid': 'fire124',
    'push-content': ': 一定可教化，所以判三個月，再喝杯酒可能變一個月',
    'push-ipdatetime': ' 04/17 11:13'},
   {'push-tag': '→ ',
    'push-userid': 'sincere77',
    'push-content': ': 沒有提告傷害？',
    'push-ipdatetime': ' 04/17 11:14'},
   {'push-tag': '噓 ',
    'push-userid': 'f0960010',
    'push-content': ': 這種才關這樣?我對台灣司法已絕望',
    'push-ipdatetime': ' 04/17 11:14'},
   {'push-tag': '推 ',
    'push-userid': 'iam0718',
    'push-content': ': 3-9個月 他們FB大概刷一波榮耀之類的 笑了 但法律人說棒',
    'push-ipdatetime': ' 04/17 11:19'},
   {'push-tag': '噓 ',
    'push-userid': 'liam0621',
    'push-content': ': 四輪重機 嘿嘿',
    'push-ipdatetime': ' 04/17 11:27'},
   {'push-tag': '→ ',
    'push-userid': 'bicedb',
    'push-content': ': 槍斃了吧 免得留後患',
    'push-ipdatetime': ' 04/17 11:36'}]},
 {'article_url': 'https://www.ptt.cc/bbs/Gossiping/M.1587091894.A.866.html',
  'auth_id': 'ousapas',
  'auth_name': 'komica123',
  'title': '[問卦] 美國國防部長軍階是中校?',
  'date': datetime.datetime(2020, 4, 17, 10, 51, 32),
  'board_name': 'Gossiping',
  'article_content': '\n美國現任國防部長Mark Esper 1986–2007在美國陸軍服役\n\n最高軍階只當到中校\n\n有沒有為何川普找中校當國防部長的八卦\n\n不會管不動下面一堆將軍嗎\n\n--\n',
  'comment_content': [{'push-tag': '推 ',
    'push-userid': 'bbdirty5566',
    'push-content': ': 教育部長也不是教育學博士阿',
    'push-ipdatetime': ' 04/17 10:52'},
   {'push-tag': '→ ',
    'push-userid': 'flarecutter',
    'push-content': ': 你應該比較在意他有沒有超能力',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '→ ',
    'push-userid': 'cytotoxic',
    'push-content': ': 退伍之後無敵星星阿',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '推 ',
    'push-userid': 'piliwu',
    'push-content': ': 部長是文職非軍職',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '推 ',
    'push-userid': 'fantasyth',
    'push-content': ': 國防部長是政治職位，跟軍職不一樣',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '推 ',
    'push-userid': 'deann',
    'push-content': ': 國防部長是文官 給女人當都可以',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '推 ',
    'push-userid': 'tigotigo',
    'push-content': ': 我國總統沒有當過兵也是三軍總司令啊',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '→ ',
    'push-userid': 'bbdirty5566',
    'push-content': ': 交通部長也不是交通學博士阿',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '→ ',
    'push-userid': 'ABON0828',
    'push-content': ': 美國國防部長是文官體制，明文規定不能是軍職...',
    'push-ipdatetime': ' 04/17 10:54'},
   {'push-tag': '→ ',
    'push-userid': 'deann',
    'push-content': ': 不然蔡英文是的軍階是?',
    'push-ipdatetime': ' 04/17 10:54'},
   {'push-tag': '推 ',
    'push-userid': 'zippy',
    'push-content': ': 利比亞頭目格達費，不是也只有上校',
    'push-ipdatetime': ' 04/17 10:54'},
   {'push-tag': '推 ',
    'push-userid': 'cccon1ine',
    'push-content': ': 國防部長很多行政管理工作吧',
    'push-ipdatetime': ' 04/17 10:54'},
   {'push-tag': '→ ',
    'push-userid': 'ABON0828',
    'push-content': ': 要當到將軍，再避過旋轉門時間...沒80也70了',
    'push-ipdatetime': ' 04/17 10:54'},
   {'push-tag': '→ ',
    'push-userid': 'cccon1ine',
    'push-content': ': 打仗要靠參謀總長',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '→ ',
    'push-userid': 'piliwu',
    'push-content': ': 麥克馬拉是美國史上任期最久的國防部長也只有中校',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '推 ',
    'push-userid': 'cytotoxic',
    'push-content': ': 因為軍職會整天叛變 跟中南美洲一樣',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '→ ',
    'push-userid': 'mega1984',
    'push-content': ': 國防部長是文官，就算找老百姓當也可以',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '→ ',
    'push-userid': 'derrick1220',
    'push-content': ': 海珊參加軍事政變時好像也是個中校',
    'push-ipdatetime': ' 04/17 10:56'},
   {'push-tag': '→ ',
    'push-userid': 'cytotoxic',
    'push-content': ': 總統制國家其實多數都有這種問題',
    'push-ipdatetime': ' 04/17 10:56'},
   {'push-tag': '→ ',
    'push-userid': 'cytotoxic',
    'push-content': ': 中華民國前期也是 我掌握軍力還聽你指揮幹嘛',
    'push-ipdatetime': ' 04/17 10:56'},
   {'push-tag': '推 ',
    'push-userid': 'piliwu',
    'push-content': ': 這是個好制度軍事是為了政治存在，決定大方向是政治問題',
    'push-ipdatetime': ' 04/17 10:57'},
   {'push-tag': '→ ',
    'push-userid': 'piliwu',
    'push-content': ': 軍事執行有參謀總長等專家',
    'push-ipdatetime': ' 04/17 10:57'},
   {'push-tag': '→ ',
    'push-userid': 'qqq87112',
    'push-content': ': 你要為中華民國一樣 沒能力當沖部長',
    'push-ipdatetime': ' 04/17 10:58'},
   {'push-tag': '推 ',
    'push-userid': 'kll95',
    'push-content': ': 這個人雖然中校但是打過不少戰事',
    'push-ipdatetime': ' 04/17 10:58'},
   {'push-tag': '→ ',
    'push-userid': 'npc776',
    'push-content': ': 華人思考 怕軍頭篡位 兵權都不敢下放',
    'push-ipdatetime': ' 04/17 10:58'},
   {'push-tag': '→ ',
    'push-userid': 'cytotoxic',
    'push-content': ': 不是華人拉 中南美非洲 都一堆國防部長叛變的',
    'push-ipdatetime': ' 04/17 10:59'},
   {'push-tag': '→ ',
    'push-userid': 'cytotoxic',
    'push-content': ': 總統制國家成功的只有美國...台灣已經算半總統制了',
    'push-ipdatetime': ' 04/17 10:59'},
   {'push-tag': '推 ',
    'push-userid': 'kevin05233',
    'push-content': ': 我國交通部長也..算了 講多了怕被告......',
    'push-ipdatetime': ' 04/17 11:01'},
   {'push-tag': '推 ',
    'push-userid': 'tf010714',
    'push-content': ': 國防部長是文官啦 要當要先退伍',
    'push-ipdatetime': ' 04/17 11:02'},
   {'push-tag': '→ ',
    'push-userid': 'tf010714',
    'push-content': ': 所以每個國防部長都是六星民人好嗎',
    'push-ipdatetime': ' 04/17 11:03'},
   {'push-tag': '→ ',
    'push-userid': 'tf010714',
    'push-content': ': 武官最高是參謀總長',
    'push-ipdatetime': ' 04/17 11:03'},
   {'push-tag': '推 ',
    'push-userid': 'realmiddle',
    'push-content': ': 不管什麼官階都比不上退伍好嗎?',
    'push-ipdatetime': ' 04/17 11:05'},
   {'push-tag': '→ ',
    'push-userid': 'upeo',
    'push-content': ': 美國中校 大概是台灣的中將',
    'push-ipdatetime': ' 04/17 11:05'},
   {'push-tag': '推 ',
    'push-userid': 'ssabjm',
    'push-content': ': 美國的中校跟台灣的中校不能比',
    'push-ipdatetime': ' 04/17 11:07'},
   {'push-tag': '推 ',
    'push-userid': 'wwwson1256',
    'push-content': ': 美國國防部長不是負責嘆氣的嗎',
    'push-ipdatetime': ' 04/17 11:09'},
   {'push-tag': '→ ',
    'push-userid': 'gh34163',
    'push-content': ': 文官...',
    'push-ipdatetime': ' 04/17 11:10'},
   {'push-tag': '→ ',
    'push-userid': 'nick0660',
    'push-content': ': 火影也是下忍啊',
    'push-ipdatetime': ' 04/17 11:12'},
   {'push-tag': '→ ',
    'push-userid': 'jpnldvh',
    'push-content': ': 火影都只有下忍了',
    'push-ipdatetime': ' 04/17 11:12'},
   {'push-tag': '推 ',
    'push-userid': 'cytotoxic',
    'push-content': ': 幹 就猜有人會提到火影XD',
    'push-ipdatetime': ' 04/17 11:15'},
   {'push-tag': '→ ',
    'push-userid': 'cytotoxic',
    'push-content': ': 不過火影比較像總統吧',
    'push-ipdatetime': ' 04/17 11:15'},
   {'push-tag': '推 ',
    'push-userid': 'pupuliao',
    'push-content': ': 美國國防部長是文官 也不負責指揮作戰',
    'push-ipdatetime': ' 04/17 11:15'},
   {'push-tag': '→ ',
    'push-userid': 'pupuliao',
    'push-content': ': 指揮作戰是各戰區指揮中心',
    'push-ipdatetime': ' 04/17 11:16'},
   {'push-tag': '推 ',
    'push-userid': 'iwinlottery',
    'push-content': ': 校級通常是實戰單位，政變校級合理吧',
    'push-ipdatetime': ' 04/17 11:16'},
   {'push-tag': '推 ',
    'push-userid': 'karevin07',
    'push-content': ': 潘文忠是博士啊',
    'push-ipdatetime': ' 04/17 11:18'},
   {'push-tag': '推 ',
    'push-userid': 'azdy',
    'push-content': ': 士官學校畢業的都可以當總統了',
    'push-ipdatetime': ' 04/17 11:20'},
   {'push-tag': '推 ',
    'push-userid': 'asole',
    'push-content': ': 現在國防部長早就是文官了 你哪個年代的',
    'push-ipdatetime': ' 04/17 11:22'},
   {'push-tag': '推 ',
    'push-userid': 'sleepyrat',
    'push-content': ': 蔡英文的軍階：絕地大師',
    'push-ipdatetime': ' 04/17 11:23'}]},
 {'article_url': 'https://www.ptt.cc/bbs/Gossiping/M.1587091929.A.9B2.html',
  'auth_id': 'Taiwanfish',
  'auth_name': '台灣鯛',
  'title': '[問卦] 其實武漢肺炎改造國家？',
  'date': datetime.datetime(2020, 4, 17, 10, 52, 7),
  'board_name': 'Gossiping',
  'article_content': '\n武漢肺炎對於三高族群、老人及胖子和慢性疾病都致死率偏高，而大家都知道老人及社會\n底層人口沒有產出，對國家社會就是負擔。\n\n藉由這次機會，讓高齡的不死老人趕快死一死，年輕世代經過洗腦教育，根本以黨為尊。\n\n\n中國大陸儘管死亡人數及疾患多，但在挺過這波疫情之後，其實戰鬥力大增。\n\n遭受重創的美國、英國、義大利等民主國家，其實也能受惠，因為死的幾乎都是老人，青\n壯世代崛起而代之是很快的。\n\n反觀台灣防疫模範生，常常早上在文山區興隆公園旁滿滿的老人，七點不到就在藥局前排\n隊了...\n\n想想這群吸國民黨奶水長大的高級外省人還能再活1.20年，靠著年輕人的勞動力領社會福\n利，不寒而慄啊。\n\n\n有沒有武漢肺炎疫情爆發的國家，痛一時，爽後面的八卦？\n\n--\n',
  'comment_content': [{'push-tag': '→ ',
    'push-userid': 'james732',
    'push-content': ': 如果死的是你親近的人你還會這麼說ㄇ',
    'push-ipdatetime': '04/17 10:52'},
   {'push-tag': '推 ',
    'push-userid': 'Julian9x9x9',
    'push-content': ': 中國社會主義式的肺炎 均貧卡',
    'push-ipdatetime': '04/17 10:52'},
   {'push-tag': '噓 ',
    'push-userid': 'flavorBZ',
    'push-content': ': 結果美國死更多，快笑死XD',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '推 ',
    'push-userid': 'touchbird',
    'push-content': ': 黑暗兵法',
    'push-ipdatetime': '04/17 10:53'},
   {'push-tag': '推 ',
    'push-userid': 'phix',
    'push-content': ': 實驗室的用途應該不是這樣',
    'push-ipdatetime': '04/17 10:53'},
   {'push-tag': '→ ',
    'push-userid': 'Julian9x9x9',
    'push-content': ': 三樓啊 人家死了你這麼開心是怎樣',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '→ ',
    'push-userid': 'flavorBZ',
    'push-content': ': 美國黑人掰掰，更讓人懷疑川普嫌疑',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '→ ',
    'push-userid': 'Julian9x9x9',
    'push-content': ': 難道是反社會人格嗎',
    'push-ipdatetime': ' 04/17 10:54'},
   {'push-tag': '→ ',
    'push-userid': 'flavorBZ',
    'push-content': ': 在說美國蒼蠅你在嗨什麼？',
    'push-ipdatetime': ' 04/17 10:54'},
   {'push-tag': '→ ',
    'push-userid': 'flavorBZ',
    'push-content': ': 難道你認為是美國人？太可怕了吧',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '→ ',
    'push-userid': 'wxWidgets',
    'push-content': ': 死亡是種解脫',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '→ ',
    'push-userid': 'jobchung',
    'push-content': ': 要是我小孩這麼想 我不會留給他一毛錢 擺明是廢渣思維',
    'push-ipdatetime': ' 04/17 10:56'},
   {'push-tag': '→ ',
    'push-userid': 'flavorBZ',
    'push-content': ': 一出手就釣到一個白癡817',
    'push-ipdatetime': ' 04/17 10:56'},
   {'push-tag': '推 ',
    'push-userid': 'iamwings',
    'push-content': ': 又不是沒有武漢肺炎就不會死亡  武漢肺炎也幫助大自然',
    'push-ipdatetime': ' 04/17 10:59'},
   {'push-tag': '→ ',
    'push-userid': 'iamwings',
    'push-content': ':  這是事實 小孩這麼想就不給他什麼 這種控制思想 才更悲',
    'push-ipdatetime': ' 04/17 10:59'},
   {'push-tag': '→ ',
    'push-userid': 'iamwings',
    'push-content': ': 崔',
    'push-ipdatetime': ' 04/17 10:59'},
   {'push-tag': '→ ',
    'push-userid': 'iamwings',
    'push-content': ': 人類 真是 可憐哪',
    'push-ipdatetime': ' 04/17 10:59'},
   {'push-tag': '推 ',
    'push-userid': 'Julian9x9x9',
    'push-content': ': 對啦 你在肺炎的文說蒼蠅 這邏輯',
    'push-ipdatetime': ' 04/17 11:00'},
   {'push-tag': '推 ',
    'push-userid': 'cck525',
    'push-content': ': 反正就靜靜地看著就是了',
    'push-ipdatetime': ' 04/17 11:09'},
   {'push-tag': '推 ',
    'push-userid': 'JamesForrest',
    'push-content': ': News一直cue中國城不曉得死幾個滯美中國人lul',
    'push-ipdatetime': ' 04/17 11:13'},
   {'push-tag': '推 ',
    'push-userid': 'Cersei',
    'push-content': ': 真武統',
    'push-ipdatetime': ' 04/17 11:38'}]},
 {'article_url': 'https://www.ptt.cc/bbs/Gossiping/M.1587091988.A.B76.html',
  'auth_id': 'nt2013',
  'auth_name': 'nt2013',
  'title': '[問卦] 會幻想小茉嗎',
  'date': datetime.datetime(2020, 4, 17, 10, 53, 6),
  'board_name': 'Gossiping',
  'article_content': '\n哈囉大家好我是塊肉老搞\n\n俗話說一白遮三醜\n\n有在關注老高的有沒有順便關注白富美妙見神小茉\n\n小茉貌似是個神奇的存在\n\n初見沒啥感覺\n\n但是越看越有一種縮噗粗奶的美\n\n有沒有鄉民也是這樣港覺的？\n\n--\n',
  'comment_content': [{'push-tag': '→ ',
    'push-userid': 'King5566',
    'push-content': ': 我要強姦你？',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '噓 ',
    'push-userid': 'easylovegame',
    'push-content': ': 誰??太早',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '推 ',
    'push-userid': 'MeeToo',
    'push-content': ': 沒奶',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '推 ',
    'push-userid': 'j31404',
    'push-content': ': 五樓都幻想老高',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '→ ',
    'push-userid': 'https',
    'push-content': ': 她的功能就是假裝聽得很起勁',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '噓 ',
    'push-userid': 'cosoa69',
    'push-content': ': 下巴很寬',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '→ ',
    'push-userid': 'israelii',
    'push-content': ': 都已經40歲的阿姨了 不是我的菜',
    'push-ipdatetime': ' 04/17 10:53'},
   {'push-tag': '推 ',
    'push-userid': 'faultless',
    'push-content': ': 只會幻想小茉莉',
    'push-ipdatetime': ' 04/17 10:54'},
   {'push-tag': '推 ',
    'push-userid': 'Corydoras',
    'push-content': ': 會 講話有氣質',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '噓 ',
    'push-userid': 'nobunaga0710',
    'push-content': ': 欸???只有我在幻想力氣嗎',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '推 ',
    'push-userid': 'Dreality',
    'push-content': ': 很會保養',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '→ ',
    'push-userid': 'wawaking1',
    'push-content': ': 噁男+1',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '推 ',
    'push-userid': 'yayawoliyau',
    'push-content': ': 力氣比較誘人',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '→ ',
    'push-userid': 'walter0914',
    'push-content': ': 我都幻想阿努那奇雌性',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '噓 ',
    'push-userid': 'kraven',
    'push-content': ': 不會  連當花瓶都沒觀賞作用',
    'push-ipdatetime': ' 04/17 10:55'},
   {'push-tag': '推 ',
    'push-userid': 'alan9064',
    'push-content': ': 只要吃男一定會幻想吧',
    'push-ipdatetime': ' 04/17 10:56'},
   {'push-tag': '推 ',
    'push-userid': 'dioradio',
    'push-content': ': 小茉都40了',
    'push-ipdatetime': ' 04/17 10:58'},
   {'push-tag': '推 ',
    'push-userid': 'z0953781935',
    'push-content': ': 她真的40看起來像20',
    'push-ipdatetime': ' 04/17 11:02'},
   {'push-tag': '推 ',
    'push-userid': 'jerry8148',
    'push-content': ': 不科學 看起來很年輕',
    'push-ipdatetime': ' 04/17 11:03'},
   {'push-tag': '推 ',
    'push-userid': 'plutox',
    'push-content': ': 你不是不是想要用你的肉棒，體會曾經有過老高肉棒溫暖的',
    'push-ipdatetime': ' 04/17 11:03'},
   {'push-tag': '→ ',
    'push-userid': 'plutox',
    'push-content': ': 肉穴？',
    'push-ipdatetime': ' 04/17 11:03'},
   {'push-tag': '→ ',
    'push-userid': 'syk1104',
    'push-content': ': 還好耶..他不是騷的那類型..幻想度有限',
    'push-ipdatetime': ' 04/17 11:06'},
   {'push-tag': '推 ',
    'push-userid': 'jojoberry',
    'push-content': ': 人家夫妻很配',
    'push-ipdatetime': ' 04/17 11:06'},
   {'push-tag': '推 ',
    'push-userid': 'e1q3z9c7',
    'push-content': ': 輕聲說話很迷人',
    'push-ipdatetime': ' 04/17 11:06'},
   {'push-tag': '→ ',
    'push-userid': 'e1q3z9c7',
    'push-content': ': 小茉還不到40= = 老高才38 我記得他比老高小兩歲以內',
    'push-ipdatetime': ' 04/17 11:07'},
   {'push-tag': '→ ',
    'push-userid': 'kkkkkktw',
    'push-content': ': 很漂亮當老婆的理想型',
    'push-ipdatetime': ' 04/17 11:24'},
   {'push-tag': '推 ',
    'push-userid': 'q123212',
    'push-content': ': 小茉聽老高放屁都如此專注 是男人都羨慕老高',
    'push-ipdatetime': ' 04/17 11:27'},
   {'push-tag': '推 ',
    'push-userid': 'stock5566',
    'push-content': ': 其實她很會藏 有一集穿泳裝才發現很有料',
    'push-ipdatetime': ' 04/17 11:27'},
   {'push-tag': '→ ',
    'push-userid': 'bbc0217',
    'push-content': ': 之前隨便看一部，只覺得是花瓶',
    'push-ipdatetime': ' 04/17 11:28'},
   {'push-tag': '推 ',
    'push-userid': 'soulboy330',
    'push-content': ': 看得出有年紀好嗎',
    'push-ipdatetime': ' 04/17 11:32'},
   {'push-tag': '推 ',
    'push-userid': 'RanceTsai',
    'push-content': ': 下巴',
    'push-ipdatetime': ' 04/17 11:34'},
   {'push-tag': '→ ',
    'push-userid': 'Fortz',
    'push-content': ': 那個 小茉比老高大一些喔 我記得',
    'push-ipdatetime': ' 04/17 11:42'},
   {'push-tag': '→ ',
    'push-userid': 'Fortz',
    'push-content': ': 還有別想了，妙見神你不適合',
    'push-ipdatetime': ' 04/17 11:42'}]},
 {'article_url': 'https://www.ptt.cc/bbs/Gossiping/M.1587092036.A.D1D.html',
  'auth_id': 'leona12',
  'auth_name': 'leona12',
  'title': 'Re: [問卦] CNN也在報導華航改名',
  'date': datetime.datetime(2020, 4, 17, 10, 53, 54),
  'board_name': 'Gossiping',
  'article_content': "\n不能改的因素都是中國因素的話\n\n就把他排除掉啊\n\n把華航切割為兩個公司\n\n華航繼續飛中港澳 反正是China airlines 飛中港澳沒問題啊。\n\n然後台灣航空飛所有跟中港澳無干的航線，\n\n歐洲（因為經過中國）\n\n歐洲幾條航線送給星宇跟長榮\n\n用歐洲換長榮幾條北美航線給台灣航空\n\n所有的延伸費用政府支付\n\n長榮如果不開心讓出航線\n\n交通部就用航權逼他就範\n\n這樣ok嗎？\n\n感覺費用對政府來說都不貴\n\n引述《el2000 (el2000)》之銘言：\n: 看到幾天前CNN的報導針對台灣在討論華航改名這件事情\n: CNN還去採訪新加坡的飛航分析師得到了”now might be an ideal time to go throug\nh\n: with it, as airlines restructure and adapt in the coming months.”的答覆\n: 甚至還說如果華航只是更改品牌名的話 航權也不必重談\n: 有沒有CNN跟新加坡也支持華航改名的掛？\n: Taiwan's largest airline considers a name change https://www.cnn.com/travel/\nar\n: ticle/china-airlines-taiwan-name-change/index.html\n\n--\n",
  'comment_content': [{'push-tag': '→ ',
    'push-userid': 'guk',
    'push-content': ': 華航跟虎航嗎？2個公司',
    'push-ipdatetime': ' 04/17 10:56'},
   {'push-tag': '推 ',
    'push-userid': 'kenyun',
    'push-content': ': 你太想當然  如果國際線沒有china airline 中國就會撿去用',
    'push-ipdatetime': ' 04/17 10:57'},
   {'push-tag': '→ ',
    'push-userid': 'kenyun',
    'push-content': ': 最好的方法還是兩家  原華航減班到不被除名程度即可',
    'push-ipdatetime': ' 04/17 10:57'},
   {'push-tag': '→ ',
    'push-userid': 'kenyun',
    'push-content': ': 剩下航班都給新台航飛',
    'push-ipdatetime': ' 04/17 10:57'},
   {'push-tag': '→ ',
    'push-userid': 'leona12',
    'push-content': ': 那國際就留新加坡就好',
    'push-ipdatetime': ' 04/17 10:59'}]}]

# %%
testInsertData = list()
# title
print(insertData[0]['title'])
# boardName
print(insertData[0]['board_name'])
# articleId
print('_'.join(insertData[0]['article_url'].split('/')[-2:]))
# authorId
print(insertData[0]['auth_id'])
# authorName
print(insertData[0]['auth_name'])
# publishedTime
print(int((insertData[0]['date'] - datetime.datetime(1970,1,1)).total_seconds()))
# canonicalUrl
print(insertData[0]['article_url'])
# createdTime
print(insertData[0]['date'].strftime("%Y-%m-%d %H:%M:%S"))
# updateTime
print(insertData[0]['date'].strftime("%Y-%m-%d %H:%M:%S"))
# pushUp
print(len([c['push-tag'] for c in insertData[0]['comment_content'] if '推' in c['push-tag']]))
# pushDown
print(len([c['push-tag'] for c in insertData[0]['comment_content'] if '噓' in c['push-tag']]))
# content
print(insertData[0]['article_content'])
# commentContent
print(str(insertData[0]['comment_content']).replace("'", "\\'"))

oneTestData = [
    insertData[0]['title'],
    insertData[0]['board_name'],
    '_'.join(insertData[0]['article_url'].split('/')[-2:]),
    insertData[0]['auth_id'],
    insertData[0]['auth_name'],
    insertData[0]['date'].strftime("%Y-%m-%d %H:%M:%S"),
    insertData[0]['article_url'],
    insertData[0]['date'].strftime("%Y-%m-%d %H:%M:%S"),
    insertData[0]['date'].strftime("%Y-%m-%d %H:%M:%S"),
    len([c['push-tag'] for c in insertData[0]['comment_content'] if '推' in c['push-tag']]),
    len([c['push-tag'] for c in insertData[0]['comment_content'] if '噓' in c['push-tag']]),
    insertData[0]['article_content'],
    str(insertData[0]['comment_content'])
]

testInsertData.append(tuple(oneTestData))
# Out:
# [新聞] 超車自撞牽拖別人竟連孕婦都打！9屁孩國
# Gossiping
# Gossiping_M.1587091888.A.2E8.html
# SakuraYui
# 櫻花蝦
# 1587120685
# https://www.ptt.cc/bbs/Gossiping/M.1587091888.A.2E8.html
# 2020-04-17 10:51:25
# 2020-04-17 10:51:25
# 18
# 13
#
# ※新聞內容含有政治人物、政府機關類、政治族群類請以[政治]為分類，違者刪除!
# 1.媒體來源:
# ※ 例如蘋果日報、自由時報（請參考版規下方的核准媒體名單）
# ettoday
#
# 2.記者署名
# ※ 沒有在這打上記者署名的新聞會被水桶14天 編輯非記者
# ※ 外電至少要有來源或編輯 如:法新社
# 徐愷昕
#
# 3.完整新聞標題:
# ※ 標題沒有完整寫出來 ---> 依照板規刪除文章
# 超車自撞牽拖別人竟連孕婦都打！9屁孩國道逼車包抄無辜　球棒狠K下場曝
#
# 4.完整新聞內文:
# ※ 社論特稿都不能貼！違者刪除（政治類水桶3個月)，貼廣告也會被刪除喔！可詳看版規
#
# 記者徐愷昕／南投報導
#
# 15名年輕人2017年7月相約墾丁旅遊，一行人北返回家途中行經國道3號南投路段時，4部
# 車中的其中1部車為超越1輛紅色廂型車，不甚自撞護欄急停，怎料又遭後方來車撞上。超
# 車自撞男子的同行友人誤以為是箱型車蛇行致車禍發生，竟集結其他3車在國道上高速逼
# 車、倒車、逆向行駛，包抄砸車攻擊廂型車上的駕駛及乘客。南投地院依妨害公眾往來安
# 全罪，判處釀禍的9人各3至9月有期徒刑。可上訴。
#
# 2017年7月間一群20多歲年輕人開著4部車南下墾丁遊玩，旅程結束北上返家途中，在行經
# 國道3號226.8K南投路段時，徐姓男子駕駛的車輛因想超越前方紅色廂型車，怎料過程中
# 竟失控擦撞護欄急停在中線車道間，隨後又被後方轎車迎面硬生撞上。
#
# 因超車差點受波及的紅色廂型車駕駛見事故發生，上前搖下車窗詢問自撞的徐男有無狀況
# 後，見他無礙便隨即離開事故現場。此時整群年輕人的其他3部車，誤以為是紅色廂型車
# 蛇行導致事故發生，但卻像沒事一樣直接離開，氣的迅速集結一塊，一同開車衝上前替朋
# 友出氣。
# ...

# %%
# insertIntoPttArticle(testInsertData)
insertIntoPttArticle(testInsertData)
# Out:
# Successfully connected!
# 1

# %%
conn = pymysql.connect(**dbconf)
print('Successfully connected!')

sql = """
INSERT INTO PTT_ARTICLE (title, boardName, articleId, authorId, authorName, publishedTime, canonicalUrl, createdTime, updateTime, pushUp, pushDown, content, commentContent) 
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

cursor = conn.cursor()
cursor.executemany(sql, testInsertData)
# cursor.execute(sql, insert_data)

cursor.close()
conn.commit()
conn.close()
# Out:
# Successfully connected!

# %%
def convertArticlesInfo(all_articles):
    # This data can be the input of connectDB.insertIntoPttArticle(insert_data)
    insertData = list()
    for row in all_articles:
        oneRowData = (
            row['title'],
            row['board_name'],
            '_'.join(row['article_url'].split('/')[-2:]),
            row['auth_id'],
            row['auth_name'],
            row['date'].strftime("%Y-%m-%d %H:%M:%S"),
            row['article_url'],
            row['date'].strftime("%Y-%m-%d %H:%M:%S"),
            row['date'].strftime("%Y-%m-%d %H:%M:%S"),
            len([c['push-tag'] for c in row['comment_content'] if '推' in c['push-tag']]),
            len([c['push-tag'] for c in row['comment_content'] if '噓' in c['push-tag']]),
            row['article_content'],
            str(row['comment_content'])
        )
        insertData.append(oneRowData)
    return insertData

insertIntoPttArticle(convertArticlesInfo(insertData))
# Out:
# Successfully connected!
# 5

# %%
getAllArticleIdInOneBoard('Gossiping')
# Out:
# Successfully connected!
# ['Gossiping_M.1587091888.A.2E8.html',
#  'Gossiping_M.1587091894.A.866.html',
#  'Gossiping_M.1587091929.A.9B2.html',
#  'Gossiping_M.1587091988.A.B76.html',
#  'Gossiping_M.1587092036.A.D1D.html']
